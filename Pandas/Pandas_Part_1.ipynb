# %% [markdown]
# # Hướng dẫn Python Pandas (Phần 1): Bắt đầu với phân tích dữ liệu - Cài đặt và tải dữ liệu

# %% [markdown]
# ##### Khai báo thư viện

# %%
import pandas as pd

# %% [markdown]
# ##### Đọc dữ liệu đầu vào

# %%
df = pd.read_csv(r".\data\survey_results_public.csv")
# Out:
# C:\Users\84936\AppData\Local\Temp\ipykernel_16724\3657901985.py:1: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r".\data\survey_results_public.csv")

# %% [markdown]
# ##### Hiển thị 15 hàng đầu tiên của dữ liệu

# %%
df.head(15)
# Out:
#     Respondent Hobby OpenSource         Country         Student  \
# 0            1   Yes         No           Kenya              No
# 1            3   Yes        Yes  United Kingdom              No
# 2            4   Yes        Yes   United States              No
# 3            5    No         No   United States              No
# 4            7   Yes         No    South Africa  Yes, part-time
# 5            8   Yes         No  United Kingdom              No
# 6            9   Yes        Yes   United States              No
# 7           10   Yes        Yes         Nigeria              No
# 8           11   Yes        Yes   United States              No
# 9           16    No        Yes           India              No
# 10          17   Yes         No           Spain              No
# 11          18   Yes        Yes           India              No
# 12          19   Yes         No         Croatia             NaN
# 13          20    No         No           India              No
# ...

# %%
df.shape
# Out:
# (98855, 129)

# %% [markdown]
# ##### Hiển thị 10 hàng cuối cùng của dữ liệu

# %%
df.tail(10)
# Out:
#        Respondent Hobby OpenSource             Country         Student  \
# 98845      101391    No        Yes               India  Yes, full-time
# 98846      101396   Yes        Yes          Azerbaijan             NaN
# 98847      101411    No         No       United States             NaN
# 98848      101432   Yes         No               India  Yes, full-time
# 98849      101478    No        Yes               India              No
# 98850      101513   Yes        Yes       United States             NaN
# 98851      101531    No        Yes               Spain  Yes, full-time
# 98852      101541   Yes        Yes               India  Yes, full-time
# 98853      101544   Yes         No  Russian Federation              No
# 98854      101548   Yes        Yes            Cambodia             NaN
#
#                                               Employment  \
# 98845                                 Employed full-time
# 98846                                 Employed full-time
# ...

# %% [markdown]
# ##### Cho biết số hàng vào số cột của dữ liệu

# %%
df.shape
# Out:
# (98855, 129)

# %% [markdown]
# ##### Cho biết thông tin về số hàng, số cột, kiểu dữ liệu tương ứng của các thuộc tính

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 97.3+ MB

# %% [markdown]
# ##### Ban đầu, dữ liệu chỉ hiển thị lên 20 cột, lệnh này để dữ liệu hiển thị lên toàn bộ 129 cột

# %%
pd.set_option("display.max_columns", 129)

# %% [markdown]
# ##### Đọc file survey_results_schema.csv chứa mô tả về các thuộc tính

# %%
schedma_df = pd.read_csv(r".\data\survey_results_schema.csv")

# %% [markdown]
# ##### Hiển thị dữ liệu

# %%
schedma_df
# Out:
#             Column                                       QuestionText
# 0       Respondent  Randomized respondent ID number (not in order ...
# 1            Hobby                            Do you code as a hobby?
# 2       OpenSource         Do you contribute to open source projects?
# 3          Country          In which country do you currently reside?
# 4          Student  Are you currently enrolled in a formal, degree...
# ..             ...                                                ...
# 124            Age  What is your age? If you prefer not to answer,...
# 125     Dependents  Do you have any children or other dependents t...
# 126     MilitaryUS  Are you currently serving or have you ever ser...
# 127  SurveyTooLong  How do you feel about the length of the survey...
# 128     SurveyEasy  How easy or difficult was this survey to compl...
#
# [129 rows x 2 columns]

# %% [markdown]
# ##### Ban đầu, dữ liệu chỉ hiển thị 20 dòng, lệnh này để dữ liệu hiện đủ 129 dòng

# %%
pd.set_option("display.max_rows", 129)
