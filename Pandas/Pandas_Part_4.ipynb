# %% [markdown]
# # Hướng dẫn Python Pandas (Phần 4): Lọc - Sử dụng các điều kiện để lọc hàng và cột

# %% [markdown]
# ## Part 1

# %% [markdown]
# ##### Khai báo thư viện

# %%
import pandas as pd

# %% [markdown]
# ##### Tạo từ điển people

# %%
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Schafer", "Doe", "Doe"], 
    "email" : ["CoreyMSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
}

# %% [markdown]
# ##### Tạo dataframe từ từ điển trên

# %%
df = pd.DataFrame(people)

# %% [markdown]
# ##### Hiển thị dataframe

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# ##### Điều kiện lọc hàng là giá trị trong cột 'last' == Doe

# %%
filt = (df['last'] == 'Doe')
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %% [markdown]
# ##### Lọc trên dataframe với điều kiện trên (3 cách đều giống nhau)

# %%
df[df['last'] == 'Doe']
df[filt]
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %% [markdown]
# ##### Áp dụng bộ lọc trên dataframe, chỉ lấy ra cột 'email'

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ##### Điều kiện lọc hàng là giá trị trong cột 'last' == Doe và first == 'Jane'

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'Jane')
filt
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %% [markdown]
# ##### Lọc trên dataframe với điều kiện trên (3 cách đều giống nhau)

# %%
df[(df['last'] == 'Doe') & (df['first'] == 'Jane')]
df[filt]
df.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com

# %% [markdown]
# ##### Áp dụng bộ lọc trên dataframe, chỉ lấy ra cột 'email'

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ##### Điều kiện lọc hàng là giá trị trong cột 'last' == Schafer hoặc first == 'John'

# %%
filt = (df['last'] == 'Schafer') | (df['first'] == 'John')
filt
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %% [markdown]
# ##### Lọc trên dataframe với điều kiện trên (3 cách đều giống nhau)

# %%
df[(df['last'] == 'Schafer') | (df['first'] == 'John')]
df[filt]
df.loc[filt]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# ##### Áp dụng bộ lọc trên dataframe, chỉ lấy ra cột 'email'

# %%
df.loc[filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ##### Điều kiện lọc hàng là giá trị trong cột 'last' |= Schafer và first != 'John'

# %% [markdown]
# ##### Lọc trên dataframe với điều kiện trên (2 cách đều giống nhau)

# %%
df[~filt] # ~: Phép phủ định điều kiện lọc trên thì thành điều kiện lọc này
df.loc[~filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com

# %% [markdown]
# ##### Áp dụng bộ lọc trên dataframe, chỉ lấy ra cột 'email'

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ## Part 2

# %% [markdown]
# ##### Đọc vào dữ liệu và dữ liệu mô tả các thuộc tính

# %%
df = pd.read_csv(r".\data\survey_results_public.csv")
schedma_df = pd.read_csv(r".\data\survey_results_schema.csv")
# Out:
# C:\Users\84936\AppData\Local\Temp\ipykernel_10336\958856146.py:1: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r".\data\survey_results_public.csv")

# %% [markdown]
# ##### Cài đặt cho số cột hiển thị là tối đa 129 cột và số hàng hiển thị tối đa là 129 hàng

# %%
pd.set_option("display.max_columns", 129)
pd.set_option("display.max_rows", 129)

# %% [markdown]
# ##### Hiển thị ra 10 hàng đầu tiên của dữ liệu

# %%
df.head(10)
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
# 5           8   Yes         No  United Kingdom              No
# 6           9   Yes        Yes   United States              No
# 7          10   Yes        Yes         Nigeria              No
# 8          11   Yes        Yes   United States              No
# 9          16    No        Yes           India              No
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
# 5  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6  Employed full-time  Some college/university study without earning ...
# 7  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8  Employed full-time  Some college/university study without earning ...
# 9  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
# 5  Computer science, computer engineering, or sof...
# 6  Computer science, computer engineering, or sof...
# 7  Computer science, computer engineering, or sof...
# 8  Fine arts or performing arts (ex. graphic desi...
# 9  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
# 5        10 to 19 employees
# 6  10,000 or more employees
# 7        10 to 19 employees
# 8      100 to 499 employees
# 9      500 to 999 employees
#
#                                              DevType       YearsCoding  \
# 0                               Full-stack developer         3-5 years
# 1  Database administrator;DevOps specialist;Full-...  30 or more years
# 2           Engineering manager;Full-stack developer       24-26 years
# 3                               Full-stack developer       18-20 years
# 4  Data or business analyst;Desktop or enterprise...         6-8 years
# 5  Back-end developer;Database administrator;Fron...         6-8 years
# 6  Back-end developer;Front-end developer;Full-st...        9-11 years
# 7  Designer;Front-end developer;QA or test developer         0-2 years
# 8  Back-end developer;C-suite executive (CEO, CTO...  30 or more years
# 9                                           Designer         0-2 years
#
#   YearsCodingProf                     JobSatisfaction  \
# 0       3-5 years                 Extremely satisfied
# 1     18-20 years             Moderately dissatisfied
# 2       6-8 years                Moderately satisfied
# 3     12-14 years  Neither satisfied nor dissatisfied
# 4       0-2 years                  Slightly satisfied
# 5       3-5 years                Moderately satisfied
# 6       0-2 years                  Slightly satisfied
# 7       3-5 years                  Slightly satisfied
# 8     21-23 years                Moderately satisfied
# 9             NaN                                 NaN
#
#                    CareerSatisfaction  \
# 0                 Extremely satisfied
# 1  Neither satisfied nor dissatisfied
# 2                Moderately satisfied
# 3               Slightly dissatisfied
# 4                Moderately satisfied
# 5                  Slightly satisfied
# 6                Moderately satisfied
# 7                Moderately satisfied
# 8                Moderately satisfied
# 9                                 NaN
#
#                                        HopeFiveYears  \
# 0  Working as a founder or co-founder of my own c...
# 1  Working in a different or more specialized tec...
# 2  Working as a founder or co-founder of my own c...
# 3  Working as a founder or co-founder of my own c...
# 4  Working in a different or more specialized tec...
# 5  Working in a different or more specialized tec...
# 6  Working as a founder or co-founder of my own c...
# 7  Working as a founder or co-founder of my own c...
# 8                                Doing the same work
# 9                                                NaN
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2  I’m not actively looking, but I am open to new...
# 3  I’m not actively looking, but I am open to new...
# 4  I’m not actively looking, but I am open to new...
# 5                    I am actively looking for a job
# 6  I’m not actively looking, but I am open to new...
# 7  I’m not actively looking, but I am open to new...
# 8  I’m not actively looking, but I am open to new...
# 9                                                NaN
#
#                   LastNewJob  AssessJob1  AssessJob2  AssessJob3  AssessJob4  \
# 0       Less than a year ago        10.0         7.0         8.0         1.0
# 1      More than 4 years ago         1.0         7.0        10.0         8.0
# 2       Less than a year ago         NaN         NaN         NaN         NaN
# 3       Less than a year ago         NaN         NaN         NaN         NaN
# 4  Between 1 and 2 years ago         8.0         5.0         7.0         1.0
# 5  Between 2 and 4 years ago         8.0         5.0         4.0         9.0
# 6       Less than a year ago         5.0         3.0         9.0         4.0
# 7       Less than a year ago         6.0         5.0         4.0         2.0
# 8  Between 2 and 4 years ago         6.0         3.0         7.0         4.0
# 9                        NaN         NaN         NaN         NaN         NaN
#
#    AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  AssessJob10  \
# 0         2.0         5.0         3.0         4.0         9.0          6.0
# 1         2.0         5.0         4.0         3.0         6.0          9.0
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         2.0         6.0         4.0         3.0        10.0          9.0
# 5         1.0         3.0         6.0         2.0        10.0          7.0
# 6         1.0         8.0         2.0         7.0        10.0          6.0
# 7         7.0         8.0        10.0         1.0         9.0          3.0
# 8         1.0         5.0        10.0         8.0         9.0          2.0
# 9         NaN         NaN         NaN         NaN         NaN          NaN
#
#    AssessBenefits1  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0              NaN              NaN              NaN              NaN
# 1              1.0              5.0              3.0              7.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              1.0             10.0              2.0              4.0
# 5              1.0              3.0              4.0             10.0
# 6              1.0              3.0              2.0              9.0
# 7              1.0              3.0              5.0              7.0
# 8              1.0              3.0              2.0              9.0
# 9              NaN              NaN              NaN              NaN
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              NaN              NaN              NaN              NaN
# 1             10.0              4.0             11.0              9.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              8.0              3.0             11.0              7.0
# 5              9.0              2.0              6.0              5.0
# 6             11.0              4.0              8.0              6.0
# 7              6.0              2.0             11.0              9.0
# 8             11.0              5.0              8.0              4.0
# 9              NaN              NaN              NaN              NaN
#
#    AssessBenefits9  AssessBenefits10  AssessBenefits11  JobContactPriorities1  \
# 0              NaN               NaN               NaN                    3.0
# 1              6.0               2.0               8.0                    3.0
# 2              NaN               NaN               NaN                    NaN
# 3              NaN               NaN               NaN                    NaN
# 4              5.0               9.0               6.0                    2.0
# 5             11.0               7.0               8.0                    4.0
# 6              7.0              10.0               5.0                    3.0
# 7              4.0              10.0               8.0                    1.0
# 8             10.0               7.0               6.0                    5.0
# 9              NaN               NaN               NaN                    NaN
#
#    JobContactPriorities2  JobContactPriorities3  JobContactPriorities4  \
# 0                    1.0                    4.0                    2.0
# 1                    1.0                    5.0                    2.0
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    1.0                    4.0                    5.0
# 5                    2.0                    5.0                    1.0
# 6                    1.0                    5.0                    4.0
# 7                    3.0                    2.0                    4.0
# 8                    1.0                    2.0                    3.0
# 9                    NaN                    NaN                    NaN
#
#    JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# 0                    5.0                  5.0                  6.0
# 1                    4.0                  1.0                  3.0
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    3.0                  7.0                  3.0
# 5                    3.0                  2.0                  6.0
# 6                    2.0                  1.0                  5.0
# 7                    5.0                  2.0                  6.0
# 8                    4.0                  3.0                  7.0
# 9                    NaN                  NaN                  NaN
#
#    JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# 0                  7.0                  2.0                  1.0
# 1                  4.0                  5.0                  2.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  6.0                  2.0                  1.0
# 5                  7.0                  3.0                  1.0
# 6                  3.0                  4.0                  2.0
# 7                  1.0                  3.0                  7.0
# 8                  2.0                  4.0                  1.0
# 9                  NaN                  NaN                  NaN
#
#    JobEmailPriorities6  JobEmailPriorities7  \
# 0                  4.0                  3.0
# 1                  6.0                  7.0
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  4.0                  5.0
# 5                  5.0                  4.0
# 6                  6.0                  7.0
# 7                  5.0                  4.0
# 8                  6.0                  5.0
# 9                  NaN                  NaN
#
#                                             UpdateCV  \
# 0     My job status or other personal status changed
# 1                  I saw an employer’s advertisement
# 2                                                NaN
# 3                           A recruiter contacted me
# 4     My job status or other personal status changed
# 5  I did not receive an expected change in compen...
# 6     My job status or other personal status changed
# 7                  I saw an employer’s advertisement
# 8     My job status or other personal status changed
# 9                                                NaN
#
#                       Currency  Salary SalaryType  ConvertedSalary  \
# 0                          NaN     NaN    Monthly              NaN
# 1  British pounds sterling (£)   51000     Yearly          70841.0
# 2                          NaN     NaN        NaN              NaN
# 3             U.S. dollars ($)     NaN        NaN              NaN
# 4      South African rands (R)  260000     Yearly          21426.0
# 5  British pounds sterling (£)   30000        NaN          41671.0
# 6             U.S. dollars ($)  120000     Yearly         120000.0
# 7                          NaN     NaN        NaN              NaN
# 8             U.S. dollars ($)  250000     Yearly         250000.0
# 9                          NaN     NaN        NaN              NaN
#
#   CurrencySymbol                                 CommunicationTools  \
# 0            KES                                              Slack
# 1            GBP  Confluence;Office / productivity suite (Micros...
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            ZAR  Office / productivity suite (Microsoft Office,...
# 5            GBP  Confluence;Jira;Office / productivity suite (M...
# 6            USD  Confluence;Office / productivity suite (Micros...
# 7            NaN  Facebook;Google Hangouts/Chat;Office / product...
# 8            USD  Confluence;HipChat;Jira;Office / productivity ...
# 9            NaN                                                NaN
#
#    TimeFullyProductive                                     EducationTypes  \
# 0  One to three months  Taught yourself a new language, framework, or ...
# 1  One to three months  Taught yourself a new language, framework, or ...
# 2                  NaN                                                NaN
# 3  Three to six months  Completed an industry certification program (e...
# 4  Three to six months  Taken a part-time in-person course in programm...
# 5    Less than a month  Received on-the-job training in software devel...
# 6   Six to nine months  Received on-the-job training in software devel...
# 7  One to three months  Taken an online course in programming or softw...
# 8  Three to six months  Taken an online course in programming or softw...
# 9                  NaN                                                NaN
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1  The official documentation and/or standards fo...
# 2                                                NaN
# 3  The official documentation and/or standards fo...
# 4  The official documentation and/or standards fo...
# 5  The official documentation and/or standards fo...
# 6  The official documentation and/or standards fo...
# 7                                                NaN
# 8  The official documentation and/or standards fo...
# 9                                                NaN
#
#               TimeAfterBootcamp  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7  Immediately after graduating
# 8                           NaN
# 9                           NaN
#
#                                     HackathonReasons  AgreeDisagree1  \
# 0                   To build my professional network  Strongly agree
# 1                                                NaN           Agree
# 2                                                NaN             NaN
# 3                                                NaN        Disagree
# 4                                                NaN  Strongly agree
# 5  To improve my general technical skills or prog...        Disagree
# 6                                                NaN        Disagree
# 7  To improve my general technical skills or prog...  Strongly agree
# 8                        Because I find it enjoyable  Strongly agree
# 9                                                NaN             NaN
#
#                AgreeDisagree2              AgreeDisagree3  \
# 0              Strongly agree  Neither Agree nor Disagree
# 1                       Agree  Neither Agree nor Disagree
# 2                         NaN                         NaN
# 3                    Disagree           Strongly disagree
# 4                       Agree           Strongly disagree
# 5  Neither Agree nor Disagree           Strongly disagree
# 6                       Agree           Strongly disagree
# 7           Strongly disagree  Neither Agree nor Disagree
# 8           Strongly disagree           Strongly disagree
# 9                         NaN                         NaN
#
#                                   LanguageWorkedWith  \
# 0                         JavaScript;Python;HTML;CSS
# 1                       JavaScript;Python;Bash/Shell
# 2                                                NaN
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                 C;C++;Java;Matlab;R;SQL;Bash/Shell
# 5         Java;JavaScript;Python;TypeScript;HTML;CSS
# 6                                JavaScript;HTML;CSS
# 7                     JavaScript;TypeScript;HTML;CSS
# 8  Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
# 9                                                NaN
#
#                               LanguageDesireNextYear  \
# 0                         JavaScript;Python;HTML;CSS
# 1                                          Go;Python
# 2                                                NaN
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4               Assembly;C;C++;Matlab;SQL;Bash/Shell
# 5  C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 6                    C;Go;JavaScript;Python;HTML;CSS
# 7                       Matlab;SQL;Kotlin;Bash/Shell
# 8                          Erlang;Go;Python;Rust;SQL
# 9                                                NaN
#
#                                   DatabaseWorkedWith  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                         Redis;PostgreSQL;Memcached
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4               SQL Server;PostgreSQL;Oracle;IBM Db2
# 5                                            MongoDB
# 6                                            MongoDB
# 7  MongoDB;MySQL;Microsoft Azure (Tables, CosmosD...
# 8  Redis;PostgreSQL;Amazon DynamoDB;Apache HBase;...
# 9                                                NaN
#
#                               DatabaseDesireNextYear  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                         PostgreSQL
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                          PostgreSQL;Oracle;IBM Db2
# 5                                         PostgreSQL
# 6                                                NaN
# 7                                                NaN
# 8  Redis;PostgreSQL;Amazon DynamoDB;Apache Hive;A...
# 9                                                NaN
#
#                             PlatformWorkedWith  \
# 0                     AWS;Azure;Linux;Firebase
# 1                                        Linux
# 2                                          NaN
# 3                                        Azure
# 4            Arduino;Windows Desktop or Server
# 5                                        Linux
# 6                                        Linux
# 7                                 Azure;Heroku
# 8  Amazon Echo;AWS;iOS;Linux;Mac OS;Serverless
# 9                                          NaN
#
#                               PlatformDesireNextYear  \
# 0                           AWS;Azure;Linux;Firebase
# 1                                              Linux
# 2                                                NaN
# 3                                              Azure
# 4                  Arduino;Windows Desktop or Server
# 5                                              Linux
# 6                                              Linux
# 7  Amazon Echo;Android;Apple Watch or Apple TV;AW...
# 8                        AWS;Linux;Mac OS;Serverless
# 9                                                NaN
#
#           FrameworkWorkedWith  FrameworkDesireNextYear  \
# 0                Django;React             Django;React
# 1                      Django                    React
# 2                         NaN                      NaN
# 3                         NaN  Angular;.NET Core;React
# 4                         NaN                      NaN
# 5             Angular;Node.js                  Node.js
# 6               Node.js;React         React;TensorFlow
# 7             Angular;Node.js         .NET Core;Django
# 8  Hadoop;Node.js;React;Spark                      NaN
# 9                         NaN                      NaN
#
#                                               IDE OperatingSystem  \
# 0                   Komodo;Vim;Visual Studio Code     Linux-based
# 1              IPython / Jupyter;Sublime Text;Vim     Linux-based
# 2                                             NaN             NaN
# 3                Visual Studio;Visual Studio Code         Windows
# 4      Notepad++;Visual Studio;Visual Studio Code         Windows
# 5             IntelliJ;PyCharm;Visual Studio Code     Linux-based
# 6                         Atom;Visual Studio Code           MacOS
# 7  Atom;Notepad++;Sublime Text;Visual Studio Code         Windows
# 8               IntelliJ;PyCharm;Sublime Text;Vim           MacOS
# 9                                             NaN             NaN
#
#   NumberMonitors                                        Methodology  \
# 0              1                                        Agile;Scrum
# 1              2                                                NaN
# 2            NaN                                                NaN
# 3              2                                 Agile;Kanban;Scrum
# 4              2  Evidence-based software engineering;Formal sta...
# 5              2                                              Agile
# 6              2                                        Agile;Scrum
# 7              1               Agile;Extreme programming (XP);Scrum
# 8              1  Agile;Evidence-based software engineering;Extr...
# 9            NaN                                                NaN
#
#       VersionControl                      CheckInCode AdBlocker  \
# 0                Git           Multiple times per day       Yes
# 1     Git;Subversion             A few times per week       Yes
# 2                NaN                              NaN       NaN
# 3                Git           Multiple times per day       Yes
# 4  Zip file back-ups  Weekly or a few times per month        No
# 5                Git             A few times per week       Yes
# 6                Git           Multiple times per day       Yes
# 7                Git           Multiple times per day       Yes
# 8                Git           Multiple times per day        No
# 9                NaN                              NaN       NaN
#
#   AdBlockerDisable                                   AdBlockerReasons  \
# 0               No                                                NaN
# 1              Yes  The website I was visiting asked me to disable it
# 2              NaN                                                NaN
# 3              Yes  The ad-blocking software was causing display i...
# 4              NaN                                                NaN
# 5              Yes  I wanted to support the website I was visiting...
# 6              Yes  The ad-blocking software was causing display i...
# 7               No                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
#
#             AdsAgreeDisagree1           AdsAgreeDisagree2  \
# 0              Strongly agree              Strongly agree
# 1              Somewhat agree  Neither agree nor disagree
# 2                         NaN                         NaN
# 3  Neither agree nor disagree              Somewhat agree
# 4              Somewhat agree              Somewhat agree
# 5              Somewhat agree              Somewhat agree
# 6           Somewhat disagree  Neither agree nor disagree
# 7              Strongly agree  Neither agree nor disagree
# 8  Neither agree nor disagree              Somewhat agree
# 9                         NaN                         NaN
#
#             AdsAgreeDisagree3  \
# 0              Strongly agree
# 1  Neither agree nor disagree
# 2                         NaN
# 3              Somewhat agree
# 4           Somewhat disagree
# 5           Somewhat disagree
# 6           Somewhat disagree
# 7           Strongly disagree
# 8  Neither agree nor disagree
# 9                         NaN
#
#                                           AdsActions  AdsPriorities1  \
# 0  Saw an online advertisement and then researche...             1.0
# 1                                                NaN             3.0
# 2                                                NaN             NaN
# 3  Stopped going to a website because of their ad...             NaN
# 4  Clicked on an online advertisement;Saw an onli...             2.0
# 5  Saw an online advertisement and then researche...             1.0
# 6  Clicked on an online advertisement;Stopped goi...             1.0
# 7  Saw an online advertisement and then researche...             NaN
# 8  Clicked on an online advertisement;Saw an onli...             1.0
# 9                                                NaN             NaN
#
#    AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# 0             5.0             4.0             7.0             2.0
# 1             5.0             1.0             4.0             6.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             3.0             4.0             6.0             1.0
# 5             3.0             4.0             2.0             7.0
# 6             4.0             2.0             5.0             3.0
# 7             NaN             NaN             NaN             NaN
# 8             3.0             5.0             4.0             2.0
# 9             NaN             NaN             NaN             NaN
#
#    AdsPriorities6  AdsPriorities7  \
# 0             6.0             3.0
# 1             7.0             2.0
# 2             NaN             NaN
# 3             NaN             NaN
# 4             7.0             5.0
# 5             5.0             6.0
# 6             7.0             6.0
# 7             NaN             NaN
# 8             7.0             6.0
# 9             NaN             NaN
#
#                                          AIDangerous  \
# 0  Artificial intelligence surpassing human intel...
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
# 5                      Increasing automation of jobs
# 6              Algorithms making important decisions
# 7  Artificial intelligence surpassing human intel...
# 8              Algorithms making important decisions
# 9                                                NaN
#
#                                        AIInteresting  \
# 0              Algorithms making important decisions
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
# 5              Algorithms making important decisions
# 6  Artificial intelligence surpassing human intel...
# 7  Evolving definitions of "fairness" in algorith...
# 8  Artificial intelligence surpassing human intel...
# 9                                                NaN
#
#                                   AIResponsible  \
# 0  The developers or the people creating the AI
# 1  The developers or the people creating the AI
# 2                                           NaN
# 3       A governmental or other regulatory body
# 4  The developers or the people creating the AI
# 5       A governmental or other regulatory body
# 6  The developers or the people creating the AI
# 7                                           NaN
# 8  The developers or the people creating the AI
# 9                                           NaN
#
#                                             AIFuture           EthicsChoice  \
# 0  I'm excited about the possibilities more than ...                     No
# 1  I'm excited about the possibilities more than ...  Depends on what it is
# 2                                                NaN                    NaN
# 3  I don't care about it, or I haven't thought ab...                     No
# 4  I'm excited about the possibilities more than ...                     No
# 5  I'm excited about the possibilities more than ...  Depends on what it is
# 6  I'm excited about the possibilities more than ...  Depends on what it is
# 7  I'm excited about the possibilities more than ...  Depends on what it is
# 8  I'm worried about the dangers more than I'm ex...                     No
# 9                                                NaN                    NaN
#
#                        EthicsReport  \
# 0                 Yes, and publicly
# 1             Depends on what it is
# 2                               NaN
# 3  Yes, but only within the company
# 4  Yes, but only within the company
# 5             Depends on what it is
# 6  Yes, but only within the company
# 7  Yes, but only within the company
# 8                 Yes, and publicly
# 9                               NaN
#
#                               EthicsResponsible    EthicalImplications  \
# 0  Upper management at the company/organization                    Yes
# 1  Upper management at the company/organization                    Yes
# 2                                           NaN                    NaN
# 3  Upper management at the company/organization                    Yes
# 4  Upper management at the company/organization                    Yes
# 5  Upper management at the company/organization  Unsure / I don't know
# 6  Upper management at the company/organization                    Yes
# 7                    The developer who wrote it                    Yes
# 8          The person who came up with the idea                    Yes
# 9                                           NaN                    NaN
#
#   StackOverflowRecommend               StackOverflowVisit  \
# 0       10 (Very Likely)           Multiple times per day
# 1       10 (Very Likely)  A few times per month or weekly
# 2                    NaN                              NaN
# 3       10 (Very Likely)             A few times per week
# 4       10 (Very Likely)            Daily or almost daily
# 5                      7  A few times per month or weekly
# 6       10 (Very Likely)           Multiple times per day
# 7       10 (Very Likely)            Daily or almost daily
# 8                      7  A few times per month or weekly
# 9                    NaN                              NaN
#
#   StackOverflowHasAccount                           StackOverflowParticipate  \
# 0                     Yes  I have never participated in Q&A on Stack Over...
# 1                     Yes                    A few times per month or weekly
# 2                     NaN                                                NaN
# 3                     Yes                    A few times per month or weekly
# 4                     Yes                Less than once per month or monthly
# 5                     Yes                Less than once per month or monthly
# 6                     Yes  I have never participated in Q&A on Stack Over...
# 7                     Yes                    A few times per month or weekly
# 8                     Yes                Less than once per month or monthly
# 9                     NaN                                                NaN
#
#                                    StackOverflowJobs  \
# 0  No, I knew that Stack Overflow had a jobs boar...
# 1                                                Yes
# 2                                                NaN
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a jobs boar...
# 5                                                Yes
# 6                                                Yes
# 7  No, I knew that Stack Overflow had a jobs boar...
# 8                                                Yes
# 9                                                NaN
#
#                         StackOverflowDevStory StackOverflowJobsRecommend  \
# 0                                         Yes                        NaN
# 1         No, I have one but it's out of date                          7
# 2                                         NaN                        NaN
# 3         No, I have one but it's out of date                          8
# 4  No, I know what it is but I don't have one                        NaN
# 5         No, I have one but it's out of date                          8
# 6         No, I have one but it's out of date                          7
# 7           No, and I don't know what that is                        NaN
# 8                                         Yes                          7
# 9                                         NaN                        NaN
#
#   StackOverflowConsiderMember       HypotheticalTools1  \
# 0                         Yes     Extremely interested
# 1                         Yes  A little bit interested
# 2                         NaN                      NaN
# 3                         Yes      Somewhat interested
# 4                         Yes     Extremely interested
# 5                          No  A little bit interested
# 6                          No          Very interested
# 7                         Yes          Very interested
# 8                          No    Not at all interested
# 9                         NaN                      NaN
#
#         HypotheticalTools2       HypotheticalTools3       HypotheticalTools4  \
# 0     Extremely interested     Extremely interested     Extremely interested
# 1  A little bit interested  A little bit interested  A little bit interested
# 2                      NaN                      NaN                      NaN
# 3      Somewhat interested      Somewhat interested      Somewhat interested
# 4     Extremely interested     Extremely interested     Extremely interested
# 5    Not at all interested          Very interested          Very interested
# 6  A little bit interested     Extremely interested          Very interested
# 7          Very interested          Very interested  A little bit interested
# 8    Not at all interested    Not at all interested    Not at all interested
# 9                      NaN                      NaN                      NaN
#
#         HypotheticalTools5                      WakeTime  HoursComputer  \
# 0     Extremely interested        Between 5:00 - 6:00 AM   9 - 12 hours
# 1  A little bit interested        Between 6:01 - 7:00 AM    5 - 8 hours
# 2                      NaN                           NaN            NaN
# 3      Somewhat interested        Between 6:01 - 7:00 AM   9 - 12 hours
# 4     Extremely interested                Before 5:00 AM  Over 12 hours
# 5     Extremely interested        Between 7:01 - 8:00 AM   9 - 12 hours
# 6          Very interested       Between 9:01 - 10:00 AM  Over 12 hours
# 7     Extremely interested  I do not have a set schedule  Over 12 hours
# 8    Not at all interested        Between 8:01 - 9:00 AM   9 - 12 hours
# 9                      NaN                           NaN            NaN
#
#            HoursOutside                  SkipMeals  \
# 0           1 - 2 hours                      Never
# 1       30 - 59 minutes                      Never
# 2                   NaN                        NaN
# 3  Less than 30 minutes       3 - 4 times per week
# 4           1 - 2 hours                      Never
# 5       30 - 59 minutes       1 - 2 times per week
# 6  Less than 30 minutes       1 - 2 times per week
# 7           1 - 2 hours  Daily or almost every day
# 8  Less than 30 minutes       1 - 2 times per week
# 9                   NaN                        NaN
#
#                             ErgonomicDevices                    Exercise  \
# 0                              Standing desk        3 - 4 times per week
# 1                Ergonomic keyboard or mouse   Daily or almost every day
# 2                                        NaN                         NaN
# 3                                        NaN  I don't typically exercise
# 4                                        NaN        3 - 4 times per week
# 5                                        NaN        1 - 2 times per week
# 6                                        NaN  I don't typically exercise
# 7                                        NaN        1 - 2 times per week
# 8  Standing desk;Fatigue-relieving floor mat  I don't typically exercise
# 9                                        NaN                         NaN
#
#    Gender         SexualOrientation  \
# 0    Male  Straight or heterosexual
# 1    Male  Straight or heterosexual
# 2     NaN                       NaN
# 3    Male  Straight or heterosexual
# 4    Male  Straight or heterosexual
# 5    Male  Straight or heterosexual
# 6    Male  Straight or heterosexual
# 7  Female                       NaN
# 8    Male  Straight or heterosexual
# 9     NaN                       NaN
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
# 5  Secondary school (e.g. American high school, G...
# 6        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7                          Primary/elementary school
# 8  Some college/university study without earning ...
# 9                                                NaN
#
#                   RaceEthnicity                Age Dependents MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes        NaN
# 1  White or of European descent  35 - 44 years old        Yes        NaN
# 2                           NaN                NaN        NaN        NaN
# 3  White or of European descent  35 - 44 years old         No         No
# 4  White or of European descent  18 - 24 years old        Yes        NaN
# 5  White or of European descent  18 - 24 years old         No        NaN
# 6  White or of European descent  18 - 24 years old         No         No
# 7   Black or of African descent  25 - 34 years old         No        NaN
# 8  White or of European descent  35 - 44 years old        Yes         No
# 9                           NaN                NaN        NaN        NaN
#
#                           SurveyTooLong          SurveyEasy
# 0  The survey was an appropriate length           Very easy
# 1  The survey was an appropriate length       Somewhat easy
# 2                                   NaN                 NaN
# 3  The survey was an appropriate length       Somewhat easy
# 4  The survey was an appropriate length       Somewhat easy
# 5  The survey was an appropriate length       Somewhat easy
# 6  The survey was an appropriate length       Somewhat easy
# 7               The survey was too long  Somewhat difficult
# 8  The survey was an appropriate length           Very easy
# 9                                   NaN                 NaN

# %% [markdown]
# ##### Hiển thị ra dữ liệu mô tả các thuộc tính

# %%
schedma_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                          Hobby
# 2                     OpenSource
# 3                        Country
# 4                        Student
# 5                     Employment
# 6                FormalEducation
# 7                 UndergradMajor
# 8                    CompanySize
# 9                        DevType
# 10                   YearsCoding
# 11               YearsCodingProf
# 12               JobSatisfaction
# 13            CareerSatisfaction
# 14                 HopeFiveYears
# 15               JobSearchStatus
# 16                    LastNewJob
# 17                    AssessJob1
# 18                    AssessJob2
# 19                    AssessJob3
# 20                    AssessJob4
# 21                    AssessJob5
# 22                    AssessJob6
# 23                    AssessJob7
# 24                    AssessJob8
# 25                    AssessJob9
# 26                   AssessJob10
# 27               AssessBenefits1
# 28               AssessBenefits2
# 29               AssessBenefits3
# 30               AssessBenefits4
# 31               AssessBenefits5
# 32               AssessBenefits6
# 33               AssessBenefits7
# 34               AssessBenefits8
# 35               AssessBenefits9
# 36              AssessBenefits10
# 37              AssessBenefits11
# 38         JobContactPriorities1
# 39         JobContactPriorities2
# 40         JobContactPriorities3
# 41         JobContactPriorities4
# 42         JobContactPriorities5
# 43           JobEmailPriorities1
# 44           JobEmailPriorities2
# 45           JobEmailPriorities3
# 46           JobEmailPriorities4
# 47           JobEmailPriorities5
# 48           JobEmailPriorities6
# 49           JobEmailPriorities7
# 50                      UpdateCV
# 51                      Currency
# 52                        Salary
# 53                    SalaryType
# 54               ConvertedSalary
# 55                CurrencySymbol
# 56            CommunicationTools
# 57           TimeFullyProductive
# 58                EducationTypes
# 59               SelfTaughtTypes
# 60             TimeAfterBootcamp
# 61              HackathonReasons
# 62                AgreeDisagree1
# 63                AgreeDisagree2
# 64                AgreeDisagree3
# 65            LanguageWorkedWith
# 66        LanguageDesireNextYear
# 67            DatabaseWorkedWith
# 68        DatabaseDesireNextYear
# 69            PlatformWorkedWith
# 70        PlatformDesireNextYear
# 71           FrameworkWorkedWith
# 72       FrameworkDesireNextYear
# 73                           IDE
# 74               OperatingSystem
# 75                NumberMonitors
# 76                   Methodology
# 77                VersionControl
# 78                   CheckInCode
# 79                     AdBlocker
# 80              AdBlockerDisable
# 81              AdBlockerReasons
# 82             AdsAgreeDisagree1
# 83             AdsAgreeDisagree2
# 84             AdsAgreeDisagree3
# 85                    AdsActions
# 86                AdsPriorities1
# 87                AdsPriorities2
# 88                AdsPriorities3
# 89                AdsPriorities4
# 90                AdsPriorities5
# 91                AdsPriorities6
# 92                AdsPriorities7
# 93                   AIDangerous
# 94                 AIInteresting
# 95                 AIResponsible
# 96                      AIFuture
# 97                  EthicsChoice
# 98                  EthicsReport
# 99             EthicsResponsible
# 100          EthicalImplications
# 101       StackOverflowRecommend
# 102           StackOverflowVisit
# 103      StackOverflowHasAccount
# 104     StackOverflowParticipate
# 105            StackOverflowJobs
# 106        StackOverflowDevStory
# 107   StackOverflowJobsRecommend
# 108  StackOverflowConsiderMember
# 109           HypotheticalTools1
# 110           HypotheticalTools2
# 111           HypotheticalTools3
# 112           HypotheticalTools4
# 113           HypotheticalTools5
# 114                     WakeTime
# 115                HoursComputer
# 116                 HoursOutside
# 117                    SkipMeals
# 118             ErgonomicDevices
# 119                     Exercise
# 120                       Gender
# 121            SexualOrientation
# 122             EducationParents
# 123                RaceEthnicity
# 124                          Age
# 125                   Dependents
# 126                   MilitaryUS
# 127                SurveyTooLong
# 128                   SurveyEasy
#
#                                           QuestionText
# 0    Randomized respondent ID number (not in order ...
# 1                              Do you code as a hobby?
# 2           Do you contribute to open source projects?
# 3            In which country do you currently reside?
# 4    Are you currently enrolled in a formal, degree...
# 5    Which of the following best describes your cur...
# 6    Which of the following best describes the high...
# 7    You previously indicated that you went to a co...
# 8    Approximately how many people are employed by ...
# 9    Which of the following describe you? Please se...
# 10   Including any education, for how many years ha...
# 11   For how many years have you coded professional...
# 12   How satisfied are you with your current job? I...
# 13   Overall, how satisfied are you with your caree...
# 14   Which of the following best describes what you...
# 15   Which of the following best describes your cur...
# 16   When was the last time that you took a job wit...
# 17   Imagine that you are assessing a potential job...
# 18   Imagine that you are assessing a potential job...
# 19   Imagine that you are assessing a potential job...
# 20   Imagine that you are assessing a potential job...
# 21   Imagine that you are assessing a potential job...
# 22   Imagine that you are assessing a potential job...
# 23   Imagine that you are assessing a potential job...
# 24   Imagine that you are assessing a potential job...
# 25   Imagine that you are assessing a potential job...
# 26   Imagine that you are assessing a potential job...
# 27   Now, imagine you are assessing a job's benefit...
# 28   Now, imagine you are assessing a job's benefit...
# 29   Now, imagine you are assessing a job's benefit...
# 30   Now, imagine you are assessing a job's benefit...
# 31   Now, imagine you are assessing a job's benefit...
# 32   Now, imagine you are assessing a job's benefit...
# 33   Now, imagine you are assessing a job's benefit...
# 34   Now, imagine you are assessing a job's benefit...
# 35   Now, imagine you are assessing a job's benefit...
# 36   Now, imagine you are assessing a job's benefit...
# 37   Now, imagine you are assessing a job's benefit...
# 38   Imagine that a company wanted to contact you a...
# 39   Imagine that a company wanted to contact you a...
# 40   Imagine that a company wanted to contact you a...
# 41   Imagine that a company wanted to contact you a...
# 42   Imagine that a company wanted to contact you a...
# 43   Imagine that same company decided to contact y...
# 44   Imagine that same company decided to contact y...
# 45   Imagine that same company decided to contact y...
# 46   Imagine that same company decided to contact y...
# 47   Imagine that same company decided to contact y...
# 48   Imagine that same company decided to contact y...
# 49   Imagine that same company decided to contact y...
# 50   Think back to the last time you updated your r...
# 51   Which currency do you use day-to-day? If your ...
# 52   What is your current gross salary (before taxe...
# 53          Is that salary weekly, monthly, or yearly?
# 54   Salary converted to annual USD salaries using ...
# 55                  Three digit currency abbreviation.
# 56   Which of the following tools do you use to com...
# 57   Suppose a new developer with four years of exp...
# 58   Which of the following types of non-degree edu...
# 59   You indicated that you had taught yourself a p...
# 60   You indicated previously that you went through...
# 61   You indicated previously that you had particip...
# 62   To what extent do you agree or disagree with e...
# 63   To what extent do you agree or disagree with e...
# 64   To what extent do you agree or disagree with e...
# 65   Which of the following programming, scripting,...
# 66   Which of the following programming, scripting,...
# 67   Which of the following database environments h...
# 68   Which of the following database environments h...
# 69   Which of the following platforms have you done...
# 70   Which of the following platforms have you done...
# 71   Which of the following libraries, frameworks, ...
# 72   Which of the following libraries, frameworks, ...
# 73   Which development environment(s) do you use re...
# 74   What is the primary operating system in which ...
# 75   How many monitors are set up at your workstation?
# 76   Which of the following methodologies do you ha...
# 77   What version control systems do you use regula...
# 78   Over the last year, how often have you checked...
# 79   Do you have ad-blocking software installed on ...
# 80   In the past month, have you disabled your ad b...
# 81   What are the reasons that you have disabled yo...
# 82   To what extent do you agree or disagree with t...
# 83   To what extent do you agree or disagree with t...
# 84   To what extent do you agree or disagree with t...
# 85   Which of the following actions have you taken ...
# 86   Please rank the following advertising qualitie...
# 87   Please rank the following advertising qualitie...
# 88   Please rank the following advertising qualitie...
# 89   Please rank the following advertising qualitie...
# 90   Please rank the following advertising qualitie...
# 91   Please rank the following advertising qualitie...
# 92   Please rank the following advertising qualitie...
# 93   What do you think is the most dangerous aspect...
# 94   What do you think is the most exciting aspect ...
# 95   Whose responsibility is it, <u>primarily</u>, ...
# 96   Overall, what's your take on the future of art...
# 97   Imagine that you were asked to write code for ...
# 98   Do you report or otherwise call out the unethi...
# 99   Who do you believe is ultimately most responsi...
# 100  Do you believe that you have an obligation to ...
# 101  How likely is it that you would recommend Stac...
# 102  How frequently would you say you visit Stack O...
# 103              Do you have a Stack Overflow account?
# 104  How frequently would you say you participate i...
# 105  Have you ever used or visited Stack Overflow J...
# 106  Do you have an up-to-date Developer Story on S...
# 107  How likely is it that you would recommend Stac...
# 108  Do you consider yourself a member of the Stack...
# 109  Please rate your interest in participating in ...
# 110  Please rate your interest in participating in ...
# 111  Please rate your interest in participating in ...
# 112  Please rate your interest in participating in ...
# 113  Please rate your interest in participating in ...
# 114  On days when you work, what time do you typica...
# 115  On a typical day, how much time do you spend o...
# 116  On a typical day, how much time do you spend o...
# 117  In a typical week, how many times do you skip ...
# 118  What ergonomic furniture or devices do you use...
# 119  In a typical week, how many times do you exerc...
# 120  Which of the following do you currently identi...
# 121  Which of the following do you currently identi...
# 122  What is the highest level of education receive...
# 123  Which of the following do you identify as? Ple...
# 124  What is your age? If you prefer not to answer,...
# 125  Do you have any children or other dependents t...
# 126  Are you currently serving or have you ever ser...
# 127  How do you feel about the length of the survey...
# 128  How easy or difficult was this survey to compl...

# %% [markdown]
# ##### Cài đặt chỉ mục cho dữ liệu là cột 'Respondent' và chỉ mục cho dữ liệu mô tả là cột 'Column'

# %%
df.set_index('Respondent', inplace=True)
schedma_df.set_index('Column', inplace=True)

# %% [markdown]
# ##### Hiển thị dữ liệu sau khi đặt chỉ mục

# %%
df.head()
# Out:
#            Hobby OpenSource         Country         Student  \
# Respondent
# 1            Yes         No           Kenya              No
# 3            Yes        Yes  United Kingdom              No
# 4            Yes        Yes   United States              No
# 5             No         No   United States              No
# 7            Yes         No    South Africa  Yes, part-time
#
#                     Employment  \
# Respondent
# 1           Employed part-time
# 3           Employed full-time
# 4           Employed full-time
# 5           Employed full-time
# 7           Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 4                 20 to 99 employees
# 5               100 to 499 employees
# 7           10,000 or more employees
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
#
#                  YearsCoding YearsCodingProf  \
# Respondent
# 1                  3-5 years       3-5 years
# 3           30 or more years     18-20 years
# 4                24-26 years       6-8 years
# 5                18-20 years     12-14 years
# 7                  6-8 years       0-2 years
#
#                                JobSatisfaction  \
# Respondent
# 1                          Extremely satisfied
# 3                      Moderately dissatisfied
# 4                         Moderately satisfied
# 5           Neither satisfied nor dissatisfied
# 7                           Slightly satisfied
#
#                             CareerSatisfaction  \
# Respondent
# 1                          Extremely satisfied
# 3           Neither satisfied nor dissatisfied
# 4                         Moderately satisfied
# 5                        Slightly dissatisfied
# 7                         Moderately satisfied
#
#                                                 HopeFiveYears  \
# Respondent
# 1           Working as a founder or co-founder of my own c...
# 3           Working in a different or more specialized tec...
# 4           Working as a founder or co-founder of my own c...
# 5           Working as a founder or co-founder of my own c...
# 7           Working in a different or more specialized tec...
#
#                                               JobSearchStatus  \
# Respondent
# 1           I’m not actively looking, but I am open to new...
# 3                             I am actively looking for a job
# 4           I’m not actively looking, but I am open to new...
# 5           I’m not actively looking, but I am open to new...
# 7           I’m not actively looking, but I am open to new...
#
#                            LastNewJob  AssessJob1  AssessJob2  AssessJob3  \
# Respondent
# 1                Less than a year ago        10.0         7.0         8.0
# 3               More than 4 years ago         1.0         7.0        10.0
# 4                Less than a year ago         NaN         NaN         NaN
# 5                Less than a year ago         NaN         NaN         NaN
# 7           Between 1 and 2 years ago         8.0         5.0         7.0
#
#             AssessJob4  AssessJob5  AssessJob6  AssessJob7  AssessJob8  \
# Respondent
# 1                  1.0         2.0         5.0         3.0         4.0
# 3                  8.0         2.0         5.0         4.0         3.0
# 4                  NaN         NaN         NaN         NaN         NaN
# 5                  NaN         NaN         NaN         NaN         NaN
# 7                  1.0         2.0         6.0         4.0         3.0
#
#             AssessJob9  AssessJob10  AssessBenefits1  AssessBenefits2  \
# Respondent
# 1                  9.0          6.0              NaN              NaN
# 3                  6.0          9.0              1.0              5.0
# 4                  NaN          NaN              NaN              NaN
# 5                  NaN          NaN              NaN              NaN
# 7                 10.0          9.0              1.0             10.0
#
#             AssessBenefits3  AssessBenefits4  AssessBenefits5  \
# Respondent
# 1                       NaN              NaN              NaN
# 3                       3.0              7.0             10.0
# 4                       NaN              NaN              NaN
# 5                       NaN              NaN              NaN
# 7                       2.0              4.0              8.0
#
#             AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# Respondent
# 1                       NaN              NaN              NaN
# 3                       4.0             11.0              9.0
# 4                       NaN              NaN              NaN
# 5                       NaN              NaN              NaN
# 7                       3.0             11.0              7.0
#
#             AssessBenefits9  AssessBenefits10  AssessBenefits11  \
# Respondent
# 1                       NaN               NaN               NaN
# 3                       6.0               2.0               8.0
# 4                       NaN               NaN               NaN
# 5                       NaN               NaN               NaN
# 7                       5.0               9.0               6.0
#
#             JobContactPriorities1  JobContactPriorities2  \
# Respondent
# 1                             3.0                    1.0
# 3                             3.0                    1.0
# 4                             NaN                    NaN
# 5                             NaN                    NaN
# 7                             2.0                    1.0
#
#             JobContactPriorities3  JobContactPriorities4  \
# Respondent
# 1                             4.0                    2.0
# 3                             5.0                    2.0
# 4                             NaN                    NaN
# 5                             NaN                    NaN
# 7                             4.0                    5.0
#
#             JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# Respondent
# 1                             5.0                  5.0                  6.0
# 3                             4.0                  1.0                  3.0
# 4                             NaN                  NaN                  NaN
# 5                             NaN                  NaN                  NaN
# 7                             3.0                  7.0                  3.0
#
#             JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# Respondent
# 1                           7.0                  2.0                  1.0
# 3                           4.0                  5.0                  2.0
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
# 7                           6.0                  2.0                  1.0
#
#             JobEmailPriorities6  JobEmailPriorities7  \
# Respondent
# 1                           4.0                  3.0
# 3                           6.0                  7.0
# 4                           NaN                  NaN
# 5                           NaN                  NaN
# 7                           4.0                  5.0
#
#                                                   UpdateCV  \
# Respondent
# 1           My job status or other personal status changed
# 3                        I saw an employer’s advertisement
# 4                                                      NaN
# 5                                 A recruiter contacted me
# 7           My job status or other personal status changed
#
#                                Currency  Salary SalaryType  ConvertedSalary  \
# Respondent
# 1                                   NaN     NaN    Monthly              NaN
# 3           British pounds sterling (£)   51000     Yearly          70841.0
# 4                                   NaN     NaN        NaN              NaN
# 5                      U.S. dollars ($)     NaN        NaN              NaN
# 7               South African rands (R)  260000     Yearly          21426.0
#
#            CurrencySymbol                                 CommunicationTools  \
# Respondent
# 1                     KES                                              Slack
# 3                     GBP  Confluence;Office / productivity suite (Micros...
# 4                     NaN                                                NaN
# 5                     NaN                                                NaN
# 7                     ZAR  Office / productivity suite (Microsoft Office,...
#
#             TimeFullyProductive  \
# Respondent
# 1           One to three months
# 3           One to three months
# 4                           NaN
# 5           Three to six months
# 7           Three to six months
#
#                                                EducationTypes  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 3           Taught yourself a new language, framework, or ...
# 4                                                         NaN
# 5           Completed an industry certification program (e...
# 7           Taken a part-time in-person course in programm...
#
#                                               SelfTaughtTypes  \
# Respondent
# 1           The official documentation and/or standards fo...
# 3           The official documentation and/or standards fo...
# 4                                                         NaN
# 5           The official documentation and/or standards fo...
# 7           The official documentation and/or standards fo...
#
#            TimeAfterBootcamp                  HackathonReasons  \
# Respondent
# 1                        NaN  To build my professional network
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# 5                        NaN                               NaN
# 7                        NaN                               NaN
#
#             AgreeDisagree1  AgreeDisagree2              AgreeDisagree3  \
# Respondent
# 1           Strongly agree  Strongly agree  Neither Agree nor Disagree
# 3                    Agree           Agree  Neither Agree nor Disagree
# 4                      NaN             NaN                         NaN
# 5                 Disagree        Disagree           Strongly disagree
# 7           Strongly agree           Agree           Strongly disagree
#
#                                           LanguageWorkedWith  \
# Respondent
# 1                                 JavaScript;Python;HTML;CSS
# 3                               JavaScript;Python;Bash/Shell
# 4                                                        NaN
# 5           C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                         C;C++;Java;Matlab;R;SQL;Bash/Shell
#
#                                       LanguageDesireNextYear  \
# Respondent
# 1                                 JavaScript;Python;HTML;CSS
# 3                                                  Go;Python
# 4                                                        NaN
# 5           C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                       Assembly;C;C++;Matlab;SQL;Bash/Shell
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1           Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 3                                  Redis;PostgreSQL;Memcached
# 4                                                         NaN
# 5           SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 7                        SQL Server;PostgreSQL;Oracle;IBM Db2
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1           Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 3                                                  PostgreSQL
# 4                                                         NaN
# 5           SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 7                                   PostgreSQL;Oracle;IBM Db2
#
#                            PlatformWorkedWith  \
# Respondent
# 1                    AWS;Azure;Linux;Firebase
# 3                                       Linux
# 4                                         NaN
# 5                                       Azure
# 7           Arduino;Windows Desktop or Server
#
#                        PlatformDesireNextYear FrameworkWorkedWith  \
# Respondent
# 1                    AWS;Azure;Linux;Firebase        Django;React
# 3                                       Linux              Django
# 4                                         NaN                 NaN
# 5                                       Azure                 NaN
# 7           Arduino;Windows Desktop or Server                 NaN
#
#             FrameworkDesireNextYear  \
# Respondent
# 1                      Django;React
# 3                             React
# 4                               NaN
# 5           Angular;.NET Core;React
# 7                               NaN
#
#                                                    IDE OperatingSystem  \
# Respondent
# 1                        Komodo;Vim;Visual Studio Code     Linux-based
# 3                   IPython / Jupyter;Sublime Text;Vim     Linux-based
# 4                                                  NaN             NaN
# 5                     Visual Studio;Visual Studio Code         Windows
# 7           Notepad++;Visual Studio;Visual Studio Code         Windows
#
#            NumberMonitors                                        Methodology  \
# Respondent
# 1                       1                                        Agile;Scrum
# 3                       2                                                NaN
# 4                     NaN                                                NaN
# 5                       2                                 Agile;Kanban;Scrum
# 7                       2  Evidence-based software engineering;Formal sta...
#
#                VersionControl                      CheckInCode AdBlocker  \
# Respondent
# 1                         Git           Multiple times per day       Yes
# 3              Git;Subversion             A few times per week       Yes
# 4                         NaN                              NaN       NaN
# 5                         Git           Multiple times per day       Yes
# 7           Zip file back-ups  Weekly or a few times per month        No
#
#            AdBlockerDisable  \
# Respondent
# 1                        No
# 3                       Yes
# 4                       NaN
# 5                       Yes
# 7                       NaN
#
#                                              AdBlockerReasons  \
# Respondent
# 1                                                         NaN
# 3           The website I was visiting asked me to disable it
# 4                                                         NaN
# 5           The ad-blocking software was causing display i...
# 7                                                         NaN
#
#                      AdsAgreeDisagree1           AdsAgreeDisagree2  \
# Respondent
# 1                       Strongly agree              Strongly agree
# 3                       Somewhat agree  Neither agree nor disagree
# 4                                  NaN                         NaN
# 5           Neither agree nor disagree              Somewhat agree
# 7                       Somewhat agree              Somewhat agree
#
#                      AdsAgreeDisagree3  \
# Respondent
# 1                       Strongly agree
# 3           Neither agree nor disagree
# 4                                  NaN
# 5                       Somewhat agree
# 7                    Somewhat disagree
#
#                                                    AdsActions  AdsPriorities1  \
# Respondent
# 1           Saw an online advertisement and then researche...             1.0
# 3                                                         NaN             3.0
# 4                                                         NaN             NaN
# 5           Stopped going to a website because of their ad...             NaN
# 7           Clicked on an online advertisement;Saw an onli...             2.0
#
#             AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# Respondent
# 1                      5.0             4.0             7.0             2.0
# 3                      5.0             1.0             4.0             6.0
# 4                      NaN             NaN             NaN             NaN
# 5                      NaN             NaN             NaN             NaN
# 7                      3.0             4.0             6.0             1.0
#
#             AdsPriorities6  AdsPriorities7  \
# Respondent
# 1                      6.0             3.0
# 3                      7.0             2.0
# 4                      NaN             NaN
# 5                      NaN             NaN
# 7                      7.0             5.0
#
#                                                   AIDangerous  \
# Respondent
# 1           Artificial intelligence surpassing human intel...
# 3                               Increasing automation of jobs
# 4                                                         NaN
# 5           Artificial intelligence surpassing human intel...
# 7                       Algorithms making important decisions
#
#                                                 AIInteresting  \
# Respondent
# 1                       Algorithms making important decisions
# 3                               Increasing automation of jobs
# 4                                                         NaN
# 5           Artificial intelligence surpassing human intel...
# 7                       Algorithms making important decisions
#
#                                            AIResponsible  \
# Respondent
# 1           The developers or the people creating the AI
# 3           The developers or the people creating the AI
# 4                                                    NaN
# 5                A governmental or other regulatory body
# 7           The developers or the people creating the AI
#
#                                                      AIFuture  \
# Respondent
# 1           I'm excited about the possibilities more than ...
# 3           I'm excited about the possibilities more than ...
# 4                                                         NaN
# 5           I don't care about it, or I haven't thought ab...
# 7           I'm excited about the possibilities more than ...
#
#                      EthicsChoice                      EthicsReport  \
# Respondent
# 1                              No                 Yes, and publicly
# 3           Depends on what it is             Depends on what it is
# 4                             NaN                               NaN
# 5                              No  Yes, but only within the company
# 7                              No  Yes, but only within the company
#
#                                        EthicsResponsible EthicalImplications  \
# Respondent
# 1           Upper management at the company/organization                 Yes
# 3           Upper management at the company/organization                 Yes
# 4                                                    NaN                 NaN
# 5           Upper management at the company/organization                 Yes
# 7           Upper management at the company/organization                 Yes
#
#            StackOverflowRecommend               StackOverflowVisit  \
# Respondent
# 1                10 (Very Likely)           Multiple times per day
# 3                10 (Very Likely)  A few times per month or weekly
# 4                             NaN                              NaN
# 5                10 (Very Likely)             A few times per week
# 7                10 (Very Likely)            Daily or almost daily
#
#            StackOverflowHasAccount  \
# Respondent
# 1                              Yes
# 3                              Yes
# 4                              NaN
# 5                              Yes
# 7                              Yes
#
#                                      StackOverflowParticipate  \
# Respondent
# 1           I have never participated in Q&A on Stack Over...
# 3                             A few times per month or weekly
# 4                                                         NaN
# 5                             A few times per month or weekly
# 7                         Less than once per month or monthly
#
#                                             StackOverflowJobs  \
# Respondent
# 1           No, I knew that Stack Overflow had a jobs boar...
# 3                                                         Yes
# 4                                                         NaN
# 5                                                         Yes
# 7           No, I knew that Stack Overflow had a jobs boar...
#
#                                  StackOverflowDevStory  \
# Respondent
# 1                                                  Yes
# 3                  No, I have one but it's out of date
# 4                                                  NaN
# 5                  No, I have one but it's out of date
# 7           No, I know what it is but I don't have one
#
#            StackOverflowJobsRecommend StackOverflowConsiderMember  \
# Respondent
# 1                                 NaN                         Yes
# 3                                   7                         Yes
# 4                                 NaN                         NaN
# 5                                   8                         Yes
# 7                                 NaN                         Yes
#
#                  HypotheticalTools1       HypotheticalTools2  \
# Respondent
# 1              Extremely interested     Extremely interested
# 3           A little bit interested  A little bit interested
# 4                               NaN                      NaN
# 5               Somewhat interested      Somewhat interested
# 7              Extremely interested     Extremely interested
#
#                  HypotheticalTools3       HypotheticalTools4  \
# Respondent
# 1              Extremely interested     Extremely interested
# 3           A little bit interested  A little bit interested
# 4                               NaN                      NaN
# 5               Somewhat interested      Somewhat interested
# 7              Extremely interested     Extremely interested
#
#                  HypotheticalTools5                WakeTime  HoursComputer  \
# Respondent
# 1              Extremely interested  Between 5:00 - 6:00 AM   9 - 12 hours
# 3           A little bit interested  Between 6:01 - 7:00 AM    5 - 8 hours
# 4                               NaN                     NaN            NaN
# 5               Somewhat interested  Between 6:01 - 7:00 AM   9 - 12 hours
# 7              Extremely interested          Before 5:00 AM  Over 12 hours
#
#                     HoursOutside             SkipMeals  \
# Respondent
# 1                    1 - 2 hours                 Never
# 3                30 - 59 minutes                 Never
# 4                            NaN                   NaN
# 5           Less than 30 minutes  3 - 4 times per week
# 7                    1 - 2 hours                 Never
#
#                        ErgonomicDevices                    Exercise Gender  \
# Respondent
# 1                         Standing desk        3 - 4 times per week   Male
# 3           Ergonomic keyboard or mouse   Daily or almost every day   Male
# 4                                   NaN                         NaN    NaN
# 5                                   NaN  I don't typically exercise   Male
# 7                                   NaN        3 - 4 times per week   Male
#
#                    SexualOrientation  \
# Respondent
# 1           Straight or heterosexual
# 3           Straight or heterosexual
# 4                                NaN
# 5           Straight or heterosexual
# 7           Straight or heterosexual
#
#                                              EducationParents  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                                         NaN
# 5           Some college/university study without earning ...
# 7           Some college/university study without earning ...
#
#                            RaceEthnicity                Age Dependents  \
# Respondent
# 1            Black or of African descent  25 - 34 years old        Yes
# 3           White or of European descent  35 - 44 years old        Yes
# 4                                    NaN                NaN        NaN
# 5           White or of European descent  35 - 44 years old         No
# 7           White or of European descent  18 - 24 years old        Yes
#
#            MilitaryUS                         SurveyTooLong     SurveyEasy
# Respondent
# 1                 NaN  The survey was an appropriate length      Very easy
# 3                 NaN  The survey was an appropriate length  Somewhat easy
# 4                 NaN                                   NaN            NaN
# 5                  No  The survey was an appropriate length  Somewhat easy
# 7                 NaN  The survey was an appropriate length  Somewhat easy

# %% [markdown]
# ##### Hiển thị dữ liệu mô tả sau khi đặt chỉ mục

# %%
schedma_df
# Out:
#                                                                   QuestionText
# Column
# Respondent                   Randomized respondent ID number (not in order ...
# Hobby                                                  Do you code as a hobby?
# OpenSource                          Do you contribute to open source projects?
# Country                              In which country do you currently reside?
# Student                      Are you currently enrolled in a formal, degree...
# Employment                   Which of the following best describes your cur...
# FormalEducation              Which of the following best describes the high...
# UndergradMajor               You previously indicated that you went to a co...
# CompanySize                  Approximately how many people are employed by ...
# DevType                      Which of the following describe you? Please se...
# YearsCoding                  Including any education, for how many years ha...
# YearsCodingProf              For how many years have you coded professional...
# JobSatisfaction              How satisfied are you with your current job? I...
# CareerSatisfaction           Overall, how satisfied are you with your caree...
# HopeFiveYears                Which of the following best describes what you...
# JobSearchStatus              Which of the following best describes your cur...
# LastNewJob                   When was the last time that you took a job wit...
# AssessJob1                   Imagine that you are assessing a potential job...
# AssessJob2                   Imagine that you are assessing a potential job...
# AssessJob3                   Imagine that you are assessing a potential job...
# AssessJob4                   Imagine that you are assessing a potential job...
# AssessJob5                   Imagine that you are assessing a potential job...
# AssessJob6                   Imagine that you are assessing a potential job...
# AssessJob7                   Imagine that you are assessing a potential job...
# AssessJob8                   Imagine that you are assessing a potential job...
# AssessJob9                   Imagine that you are assessing a potential job...
# AssessJob10                  Imagine that you are assessing a potential job...
# AssessBenefits1              Now, imagine you are assessing a job's benefit...
# AssessBenefits2              Now, imagine you are assessing a job's benefit...
# AssessBenefits3              Now, imagine you are assessing a job's benefit...
# AssessBenefits4              Now, imagine you are assessing a job's benefit...
# AssessBenefits5              Now, imagine you are assessing a job's benefit...
# AssessBenefits6              Now, imagine you are assessing a job's benefit...
# AssessBenefits7              Now, imagine you are assessing a job's benefit...
# AssessBenefits8              Now, imagine you are assessing a job's benefit...
# AssessBenefits9              Now, imagine you are assessing a job's benefit...
# AssessBenefits10             Now, imagine you are assessing a job's benefit...
# AssessBenefits11             Now, imagine you are assessing a job's benefit...
# JobContactPriorities1        Imagine that a company wanted to contact you a...
# JobContactPriorities2        Imagine that a company wanted to contact you a...
# JobContactPriorities3        Imagine that a company wanted to contact you a...
# JobContactPriorities4        Imagine that a company wanted to contact you a...
# JobContactPriorities5        Imagine that a company wanted to contact you a...
# JobEmailPriorities1          Imagine that same company decided to contact y...
# JobEmailPriorities2          Imagine that same company decided to contact y...
# JobEmailPriorities3          Imagine that same company decided to contact y...
# JobEmailPriorities4          Imagine that same company decided to contact y...
# JobEmailPriorities5          Imagine that same company decided to contact y...
# JobEmailPriorities6          Imagine that same company decided to contact y...
# JobEmailPriorities7          Imagine that same company decided to contact y...
# UpdateCV                     Think back to the last time you updated your r...
# Currency                     Which currency do you use day-to-day? If your ...
# Salary                       What is your current gross salary (before taxe...
# SalaryType                          Is that salary weekly, monthly, or yearly?
# ConvertedSalary              Salary converted to annual USD salaries using ...
# CurrencySymbol                              Three digit currency abbreviation.
# CommunicationTools           Which of the following tools do you use to com...
# TimeFullyProductive          Suppose a new developer with four years of exp...
# EducationTypes               Which of the following types of non-degree edu...
# SelfTaughtTypes              You indicated that you had taught yourself a p...
# TimeAfterBootcamp            You indicated previously that you went through...
# HackathonReasons             You indicated previously that you had particip...
# AgreeDisagree1               To what extent do you agree or disagree with e...
# AgreeDisagree2               To what extent do you agree or disagree with e...
# AgreeDisagree3               To what extent do you agree or disagree with e...
# LanguageWorkedWith           Which of the following programming, scripting,...
# LanguageDesireNextYear       Which of the following programming, scripting,...
# DatabaseWorkedWith           Which of the following database environments h...
# DatabaseDesireNextYear       Which of the following database environments h...
# PlatformWorkedWith           Which of the following platforms have you done...
# PlatformDesireNextYear       Which of the following platforms have you done...
# FrameworkWorkedWith          Which of the following libraries, frameworks, ...
# FrameworkDesireNextYear      Which of the following libraries, frameworks, ...
# IDE                          Which development environment(s) do you use re...
# OperatingSystem              What is the primary operating system in which ...
# NumberMonitors               How many monitors are set up at your workstation?
# Methodology                  Which of the following methodologies do you ha...
# VersionControl               What version control systems do you use regula...
# CheckInCode                  Over the last year, how often have you checked...
# AdBlocker                    Do you have ad-blocking software installed on ...
# AdBlockerDisable             In the past month, have you disabled your ad b...
# AdBlockerReasons             What are the reasons that you have disabled yo...
# AdsAgreeDisagree1            To what extent do you agree or disagree with t...
# AdsAgreeDisagree2            To what extent do you agree or disagree with t...
# AdsAgreeDisagree3            To what extent do you agree or disagree with t...
# AdsActions                   Which of the following actions have you taken ...
# AdsPriorities1               Please rank the following advertising qualitie...
# AdsPriorities2               Please rank the following advertising qualitie...
# AdsPriorities3               Please rank the following advertising qualitie...
# AdsPriorities4               Please rank the following advertising qualitie...
# AdsPriorities5               Please rank the following advertising qualitie...
# AdsPriorities6               Please rank the following advertising qualitie...
# AdsPriorities7               Please rank the following advertising qualitie...
# AIDangerous                  What do you think is the most dangerous aspect...
# AIInteresting                What do you think is the most exciting aspect ...
# AIResponsible                Whose responsibility is it, <u>primarily</u>, ...
# AIFuture                     Overall, what's your take on the future of art...
# EthicsChoice                 Imagine that you were asked to write code for ...
# EthicsReport                 Do you report or otherwise call out the unethi...
# EthicsResponsible            Who do you believe is ultimately most responsi...
# EthicalImplications          Do you believe that you have an obligation to ...
# StackOverflowRecommend       How likely is it that you would recommend Stac...
# StackOverflowVisit           How frequently would you say you visit Stack O...
# StackOverflowHasAccount                  Do you have a Stack Overflow account?
# StackOverflowParticipate     How frequently would you say you participate i...
# StackOverflowJobs            Have you ever used or visited Stack Overflow J...
# StackOverflowDevStory        Do you have an up-to-date Developer Story on S...
# StackOverflowJobsRecommend   How likely is it that you would recommend Stac...
# StackOverflowConsiderMember  Do you consider yourself a member of the Stack...
# HypotheticalTools1           Please rate your interest in participating in ...
# HypotheticalTools2           Please rate your interest in participating in ...
# HypotheticalTools3           Please rate your interest in participating in ...
# HypotheticalTools4           Please rate your interest in participating in ...
# HypotheticalTools5           Please rate your interest in participating in ...
# WakeTime                     On days when you work, what time do you typica...
# HoursComputer                On a typical day, how much time do you spend o...
# HoursOutside                 On a typical day, how much time do you spend o...
# SkipMeals                    In a typical week, how many times do you skip ...
# ErgonomicDevices             What ergonomic furniture or devices do you use...
# Exercise                     In a typical week, how many times do you exerc...
# Gender                       Which of the following do you currently identi...
# SexualOrientation            Which of the following do you currently identi...
# EducationParents             What is the highest level of education receive...
# RaceEthnicity                Which of the following do you identify as? Ple...
# Age                          What is your age? If you prefer not to answer,...
# Dependents                   Do you have any children or other dependents t...
# MilitaryUS                   Are you currently serving or have you ever ser...
# SurveyTooLong                How do you feel about the length of the survey...
# SurveyEasy                   How easy or difficult was this survey to compl...

# %% [markdown]
# ##### Đưa ra bộ lọc với điều kiện là giá trị trong cột 'ConvertSalary' >70000

# %%
high_salary = (df['ConvertedSalary']>70000)
high_salary.value_counts()
# Out:
# ConvertedSalary
# False    80689
# True     18166
# Name: count, dtype: int64

# %% [markdown]
# ##### Áp dụng bộ lọc trên với dữ liệu

# %%
df.loc[high_salary].head()
# Out:
#            Hobby OpenSource         Country Student          Employment  \
# Respondent
# 3            Yes        Yes  United Kingdom      No  Employed full-time
# 9            Yes        Yes   United States      No  Employed full-time
# 11           Yes        Yes   United States      No  Employed full-time
# 33           Yes        Yes       Australia      No  Employed full-time
# 38           Yes         No   United States      No  Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 11          Some college/university study without earning ...
# 33                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38          Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 3           A natural science (ex. biology, chemistry, phy...
# 9           Computer science, computer engineering, or sof...
# 11          Fine arts or performing arts (ex. graphic desi...
# 33          Another engineering discipline (ex. civil, ele...
# 38                                                        NaN
#
#                          CompanySize  \
# Respondent
# 3           10,000 or more employees
# 9           10,000 or more employees
# 11              100 to 499 employees
# 33          1,000 to 4,999 employees
# 38                10 to 19 employees
#
#                                                       DevType  \
# Respondent
# 3           Database administrator;DevOps specialist;Full-...
# 9           Back-end developer;Front-end developer;Full-st...
# 11          Back-end developer;C-suite executive (CEO, CTO...
# 33          Database administrator;Full-stack developer;Mo...
# 38          Back-end developer;Database administrator;DevO...
#
#                  YearsCoding YearsCodingProf          JobSatisfaction  \
# Respondent
# 3           30 or more years     18-20 years  Moderately dissatisfied
# 9                 9-11 years       0-2 years       Slightly satisfied
# 11          30 or more years     21-23 years     Moderately satisfied
# 33               15-17 years     12-14 years       Slightly satisfied
# 38               18-20 years     18-20 years    Slightly dissatisfied
#
#                             CareerSatisfaction  \
# Respondent
# 3           Neither satisfied nor dissatisfied
# 9                         Moderately satisfied
# 11                        Moderately satisfied
# 33                       Slightly dissatisfied
# 38                       Slightly dissatisfied
#
#                                                 HopeFiveYears  \
# Respondent
# 3           Working in a different or more specialized tec...
# 9           Working as a founder or co-founder of my own c...
# 11                                        Doing the same work
# 33          Working in a different or more specialized tec...
# 38          Working in a career completely unrelated to so...
#
#                                               JobSearchStatus  \
# Respondent
# 3                             I am actively looking for a job
# 9           I’m not actively looking, but I am open to new...
# 11          I’m not actively looking, but I am open to new...
# 33          I’m not actively looking, but I am open to new...
# 38          I’m not actively looking, but I am open to new...
#
#                            LastNewJob  AssessJob1  AssessJob2  AssessJob3  \
# Respondent
# 3               More than 4 years ago         1.0         7.0        10.0
# 9                Less than a year ago         5.0         3.0         9.0
# 11          Between 2 and 4 years ago         6.0         3.0         7.0
# 33          Between 2 and 4 years ago         7.0         4.0        10.0
# 38          Between 1 and 2 years ago        10.0         9.0         7.0
#
#             AssessJob4  AssessJob5  AssessJob6  AssessJob7  AssessJob8  \
# Respondent
# 3                  8.0         2.0         5.0         4.0         3.0
# 9                  4.0         1.0         8.0         2.0         7.0
# 11                 4.0         1.0         5.0        10.0         8.0
# 33                 2.0         1.0         5.0         3.0         6.0
# 38                 1.0         3.0         5.0         2.0         6.0
#
#             AssessJob9  AssessJob10  AssessBenefits1  AssessBenefits2  \
# Respondent
# 3                  6.0          9.0              1.0              5.0
# 9                 10.0          6.0              1.0              3.0
# 11                 9.0          2.0              1.0              3.0
# 33                 9.0          8.0              3.0              1.0
# 38                 4.0          8.0              1.0              8.0
#
#             AssessBenefits3  AssessBenefits4  AssessBenefits5  \
# Respondent
# 3                       3.0              7.0             10.0
# 9                       2.0              9.0             11.0
# 11                      2.0              9.0             11.0
# 33                      6.0              4.0              5.0
# 38                      3.0              6.0             10.0
#
#             AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# Respondent
# 3                       4.0             11.0              9.0
# 9                       4.0              8.0              6.0
# 11                      5.0              8.0              4.0
# 33                      8.0              9.0              7.0
# 38                      4.0              9.0              5.0
#
#             AssessBenefits9  AssessBenefits10  AssessBenefits11  \
# Respondent
# 3                       6.0               2.0               8.0
# 9                       7.0              10.0               5.0
# 11                     10.0               7.0               6.0
# 33                      2.0              11.0              10.0
# 38                      7.0              11.0               2.0
#
#             JobContactPriorities1  JobContactPriorities2  \
# Respondent
# 3                             3.0                    1.0
# 9                             3.0                    1.0
# 11                            5.0                    1.0
# 33                            2.0                    1.0
# 38                            4.0                    1.0
#
#             JobContactPriorities3  JobContactPriorities4  \
# Respondent
# 3                             5.0                    2.0
# 9                             5.0                    4.0
# 11                            2.0                    3.0
# 33                            4.0                    3.0
# 38                            5.0                    3.0
#
#             JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# Respondent
# 3                             4.0                  1.0                  3.0
# 9                             2.0                  1.0                  5.0
# 11                            4.0                  3.0                  7.0
# 33                            5.0                  7.0                  3.0
# 38                            2.0                  6.0                  7.0
#
#             JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# Respondent
# 3                           4.0                  5.0                  2.0
# 9                           3.0                  4.0                  2.0
# 11                          2.0                  4.0                  1.0
# 33                          4.0                  5.0                  2.0
# 38                          2.0                  3.0                  1.0
#
#             JobEmailPriorities6  JobEmailPriorities7  \
# Respondent
# 3                           6.0                  7.0
# 9                           6.0                  7.0
# 11                          6.0                  5.0
# 33                          1.0                  6.0
# 38                          5.0                  4.0
#
#                                                      UpdateCV  \
# Respondent
# 3                           I saw an employer’s advertisement
# 9              My job status or other personal status changed
# 11             My job status or other personal status changed
# 33                          I saw an employer’s advertisement
# 38          I had a negative experience or interaction at ...
#
#                                Currency  Salary SalaryType  ConvertedSalary  \
# Respondent
# 3           British pounds sterling (£)   51000     Yearly          70841.0
# 9                      U.S. dollars ($)  120000     Yearly         120000.0
# 11                     U.S. dollars ($)  250000     Yearly         250000.0
# 33              Australian dollars (A$)  120000     Yearly          95968.0
# 38                     U.S. dollars ($)   75000     Yearly          75000.0
#
#            CurrencySymbol                                 CommunicationTools  \
# Respondent
# 3                     GBP  Confluence;Office / productivity suite (Micros...
# 9                     USD  Confluence;Office / productivity suite (Micros...
# 11                    USD  Confluence;HipChat;Jira;Office / productivity ...
# 33                    AUD  Confluence;Jira;Office / productivity suite (M...
# 38                    USD                    Google Hangouts/Chat;Jira;Slack
#
#             TimeFullyProductive  \
# Respondent
# 3           One to three months
# 9            Six to nine months
# 11          Three to six months
# 33            Less than a month
# 38            Less than a month
#
#                                                EducationTypes  \
# Respondent
# 3           Taught yourself a new language, framework, or ...
# 9           Received on-the-job training in software devel...
# 11          Taken an online course in programming or softw...
# 33          Taken an online course in programming or softw...
# 38          Participated in a full-time developer training...
#
#                                               SelfTaughtTypes  \
# Respondent
# 3           The official documentation and/or standards fo...
# 9           The official documentation and/or standards fo...
# 11          The official documentation and/or standards fo...
# 33          The official documentation and/or standards fo...
# 38          The official documentation and/or standards fo...
#
#                                             TimeAfterBootcamp  \
# Respondent
# 3                                                         NaN
# 9                                                         NaN
# 11                                                        NaN
# 33                                                        NaN
# 38          I already had a full-time job as a developer w...
#
#                                              HackathonReasons  AgreeDisagree1  \
# Respondent
# 3                                                         NaN           Agree
# 9                                                         NaN        Disagree
# 11                                Because I find it enjoyable  Strongly agree
# 33          To improve my general technical skills or prog...           Agree
# 38          To improve my general technical skills or prog...  Strongly agree
#
#                         AgreeDisagree2              AgreeDisagree3  \
# Respondent
# 3                                Agree  Neither Agree nor Disagree
# 9                                Agree           Strongly disagree
# 11                   Strongly disagree           Strongly disagree
# 33          Neither Agree nor Disagree           Strongly disagree
# 38                            Disagree  Neither Agree nor Disagree
#
#                                            LanguageWorkedWith  \
# Respondent
# 3                                JavaScript;Python;Bash/Shell
# 9                                         JavaScript;HTML;CSS
# 11          Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
# 33                                  C;C++;Go;Python;SQL;Swift
# 38                     JavaScript;PHP;SQL;HTML;CSS;Bash/Shell
#
#                       LanguageDesireNextYear  \
# Respondent
# 3                                  Go;Python
# 9            C;Go;JavaScript;Python;HTML;CSS
# 11                 Erlang;Go;Python;Rust;SQL
# 33          C;C++;Go;Python;SQL;Swift;Kotlin
# 38                            PHP;Bash/Shell
#
#                                            DatabaseWorkedWith  \
# Respondent
# 3                                  Redis;PostgreSQL;Memcached
# 9                                                     MongoDB
# 11          Redis;PostgreSQL;Amazon DynamoDB;Apache HBase;...
# 33                                    Redis;PostgreSQL;SQLite
# 38                    MongoDB;MySQL;MariaDB;Amazon RDS/Aurora
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 3                                                  PostgreSQL
# 9                                                         NaN
# 11          Redis;PostgreSQL;Amazon DynamoDB;Apache Hive;A...
# 33                    Redis;PostgreSQL;SQLite;Google BigQuery
# 38          MongoDB;MySQL;SQLite;MariaDB;Amazon DynamoDB;A...
#
#                                      PlatformWorkedWith  \
# Respondent
# 3                                                 Linux
# 9                                                 Linux
# 11          Amazon Echo;AWS;iOS;Linux;Mac OS;Serverless
# 33                Android;AWS;iOS;Linux;Mac OS;Firebase
# 38                                                  NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 3                                                       Linux
# 9                                                       Linux
# 11                                AWS;Linux;Mac OS;Serverless
# 33          Android;AWS;Google Cloud Platform/App Engine;i...
# 38             Android;Arduino;Google Home;Linux;Raspberry Pi
#
#                    FrameworkWorkedWith     FrameworkDesireNextYear  \
# Respondent
# 3                               Django                       React
# 9                        Node.js;React            React;TensorFlow
# 11          Hadoop;Node.js;React;Spark                         NaN
# 33                     Angular;Node.js  Angular;Node.js;TensorFlow
# 38                                 NaN                         NaN
#
#                                                           IDE OperatingSystem  \
# Respondent
# 3                          IPython / Jupyter;Sublime Text;Vim     Linux-based
# 9                                     Atom;Visual Studio Code           MacOS
# 11                          IntelliJ;PyCharm;Sublime Text;Vim           MacOS
# 33          Android Studio;Sublime Text;Visual Studio Code...           MacOS
# 38                                    Atom;Notepad++;PHPStorm           MacOS
#
#            NumberMonitors                                        Methodology  \
# Respondent
# 3                       2                                                NaN
# 9                       2                                        Agile;Scrum
# 11                      1  Agile;Evidence-based software engineering;Extr...
# 33                      1  Agile;Extreme programming (XP);Formal standard...
# 38                      3                Agile;Kanban;Pair programming;Scrum
#
#             VersionControl             CheckInCode AdBlocker AdBlockerDisable  \
# Respondent
# 3           Git;Subversion    A few times per week       Yes              Yes
# 9                      Git  Multiple times per day       Yes              Yes
# 11                     Git  Multiple times per day        No              NaN
# 33                     Git  Multiple times per day       Yes              Yes
# 38                     Git  Multiple times per day        No              NaN
#
#                                              AdBlockerReasons  \
# Respondent
# 3           The website I was visiting asked me to disable it
# 9           The ad-blocking software was causing display i...
# 11                                                        NaN
# 33          The ad-blocking software was causing display i...
# 38                                                        NaN
#
#                      AdsAgreeDisagree1           AdsAgreeDisagree2  \
# Respondent
# 3                       Somewhat agree  Neither agree nor disagree
# 9                    Somewhat disagree  Neither agree nor disagree
# 11          Neither agree nor disagree              Somewhat agree
# 33                   Somewhat disagree  Neither agree nor disagree
# 38          Neither agree nor disagree  Neither agree nor disagree
#
#                      AdsAgreeDisagree3  \
# Respondent
# 3           Neither agree nor disagree
# 9                    Somewhat disagree
# 11          Neither agree nor disagree
# 33                      Somewhat agree
# 38                      Somewhat agree
#
#                                                    AdsActions  AdsPriorities1  \
# Respondent
# 3                                                         NaN             3.0
# 9           Clicked on an online advertisement;Stopped goi...             1.0
# 11          Clicked on an online advertisement;Saw an onli...             1.0
# 33                                                        NaN             2.0
# 38          Clicked on an online advertisement;Saw an onli...             1.0
#
#             AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# Respondent
# 3                      5.0             1.0             4.0             6.0
# 9                      4.0             2.0             5.0             3.0
# 11                     3.0             5.0             4.0             2.0
# 33                     3.0             1.0             7.0             6.0
# 38                     7.0             3.0             2.0             5.0
#
#             AdsPriorities6  AdsPriorities7  \
# Respondent
# 3                      7.0             2.0
# 9                      7.0             6.0
# 11                     7.0             6.0
# 33                     4.0             5.0
# 38                     4.0             6.0
#
#                                                   AIDangerous  \
# Respondent
# 3                               Increasing automation of jobs
# 9                       Algorithms making important decisions
# 11                      Algorithms making important decisions
# 33                              Increasing automation of jobs
# 38          Artificial intelligence surpassing human intel...
#
#                                                 AIInteresting  \
# Respondent
# 3                               Increasing automation of jobs
# 9           Artificial intelligence surpassing human intel...
# 11          Artificial intelligence surpassing human intel...
# 33          Artificial intelligence surpassing human intel...
# 38          Artificial intelligence surpassing human intel...
#
#                                            AIResponsible  \
# Respondent
# 3           The developers or the people creating the AI
# 9           The developers or the people creating the AI
# 11          The developers or the people creating the AI
# 33                            Prominent industry leaders
# 38          The developers or the people creating the AI
#
#                                                      AIFuture  \
# Respondent
# 3           I'm excited about the possibilities more than ...
# 9           I'm excited about the possibilities more than ...
# 11          I'm worried about the dangers more than I'm ex...
# 33          I'm excited about the possibilities more than ...
# 38          I'm excited about the possibilities more than ...
#
#                      EthicsChoice                      EthicsReport  \
# Respondent
# 3           Depends on what it is             Depends on what it is
# 9           Depends on what it is  Yes, but only within the company
# 11                             No                 Yes, and publicly
# 33                             No  Yes, but only within the company
# 38                             No             Depends on what it is
#
#                                        EthicsResponsible EthicalImplications  \
# Respondent
# 3           Upper management at the company/organization                 Yes
# 9           Upper management at the company/organization                 Yes
# 11                  The person who came up with the idea                 Yes
# 33                            The developer who wrote it                 Yes
# 38          Upper management at the company/organization                 Yes
#
#            StackOverflowRecommend               StackOverflowVisit  \
# Respondent
# 3                10 (Very Likely)  A few times per month or weekly
# 9                10 (Very Likely)           Multiple times per day
# 11                              7  A few times per month or weekly
# 33                              9            Daily or almost daily
# 38               10 (Very Likely)            Daily or almost daily
#
#            StackOverflowHasAccount  \
# Respondent
# 3                              Yes
# 9                              Yes
# 11                             Yes
# 33                             Yes
# 38                             Yes
#
#                                      StackOverflowParticipate  \
# Respondent
# 3                             A few times per month or weekly
# 9           I have never participated in Q&A on Stack Over...
# 11                        Less than once per month or monthly
# 33                        Less than once per month or monthly
# 38                        Less than once per month or monthly
#
#            StackOverflowJobs                       StackOverflowDevStory  \
# Respondent
# 3                        Yes         No, I have one but it's out of date
# 9                        Yes         No, I have one but it's out of date
# 11                       Yes                                         Yes
# 33                       Yes  No, I know what it is but I don't have one
# 38                       Yes           No, and I don't know what that is
#
#            StackOverflowJobsRecommend StackOverflowConsiderMember  \
# Respondent
# 3                                   7                         Yes
# 9                                   7                          No
# 11                                  7                          No
# 33                                  6                          No
# 38                                  5                          No
#
#                  HypotheticalTools1       HypotheticalTools2  \
# Respondent
# 3           A little bit interested  A little bit interested
# 9                   Very interested  A little bit interested
# 11            Not at all interested    Not at all interested
# 33          A little bit interested    Not at all interested
# 38          A little bit interested      Somewhat interested
#
#                  HypotheticalTools3       HypotheticalTools4  \
# Respondent
# 3           A little bit interested  A little bit interested
# 9              Extremely interested          Very interested
# 11            Not at all interested    Not at all interested
# 33              Somewhat interested      Somewhat interested
# 38          A little bit interested  A little bit interested
#
#                  HypotheticalTools5                 WakeTime  HoursComputer  \
# Respondent
# 3           A little bit interested   Between 6:01 - 7:00 AM    5 - 8 hours
# 9                   Very interested  Between 9:01 - 10:00 AM  Over 12 hours
# 11            Not at all interested   Between 8:01 - 9:00 AM   9 - 12 hours
# 33          A little bit interested   Between 6:01 - 7:00 AM   9 - 12 hours
# 38              Somewhat interested   Between 7:01 - 8:00 AM    5 - 8 hours
#
#                     HoursOutside                  SkipMeals  \
# Respondent
# 3                30 - 59 minutes                      Never
# 9           Less than 30 minutes       1 - 2 times per week
# 11          Less than 30 minutes       1 - 2 times per week
# 33               30 - 59 minutes                      Never
# 38          Less than 30 minutes  Daily or almost every day
#
#                                      ErgonomicDevices  \
# Respondent
# 3                         Ergonomic keyboard or mouse
# 9                                                 NaN
# 11          Standing desk;Fatigue-relieving floor mat
# 33                        Ergonomic keyboard or mouse
# 38                                                NaN
#
#                               Exercise  \
# Respondent
# 3            Daily or almost every day
# 9           I don't typically exercise
# 11          I don't typically exercise
# 33                3 - 4 times per week
# 38          I don't typically exercise
#
#                                                        Gender  \
# Respondent
# 3                                                        Male
# 9                                                        Male
# 11                                                       Male
# 33                                                       Male
# 38          Female;Male;Transgender;Non-binary, genderquee...
#
#                    SexualOrientation  \
# Respondent
# 3           Straight or heterosexual
# 9           Straight or heterosexual
# 11          Straight or heterosexual
# 33          Straight or heterosexual
# 38                               NaN
#
#                                              EducationParents  \
# Respondent
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9                 Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11          Some college/university study without earning ...
# 33                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38                  They never completed any formal education
#
#                            RaceEthnicity                Age Dependents  \
# Respondent
# 3           White or of European descent  35 - 44 years old        Yes
# 9           White or of European descent  18 - 24 years old         No
# 11          White or of European descent  35 - 44 years old        Yes
# 33                                   NaN  35 - 44 years old        Yes
# 38          White or of European descent  45 - 54 years old        Yes
#
#            MilitaryUS                         SurveyTooLong  \
# Respondent
# 3                 NaN  The survey was an appropriate length
# 9                  No  The survey was an appropriate length
# 11                 No  The survey was an appropriate length
# 33                NaN               The survey was too long
# 38                 No               The survey was too long
#
#                             SurveyEasy
# Respondent
# 3                        Somewhat easy
# 9                        Somewhat easy
# 11                           Very easy
# 33          Neither easy nor difficult
# 38                           Very easy

# %% [markdown]
# ##### Áp dụng bộ lọc trên và in ra các cột 'Country', 'LanguageWorkedWith', 'ConvertedSalary'

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedSalary']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 3           United Kingdom                       JavaScript;Python;Bash/Shell
# 9            United States                                JavaScript;HTML;CSS
# 11           United States  Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
# 33               Australia                          C;C++;Go;Python;SQL;Swift
# 38           United States             JavaScript;PHP;SQL;HTML;CSS;Bash/Shell
# ...                    ...                                                ...
# 78176        United States                                           Python;R
# 83161               Canada                 Assembly;C;C++;JavaScript;HTML;CSS
# 92974          South Korea                                         Python;VBA
# 96174               France  Assembly;C;C++;Go;Haskell;Java;JavaScript;Pyth...
# 99868       United Kingdom             Assembly;C;C++;Java;Python;Scala;Ocaml
#
#             ConvertedSalary
# Respondent
# 3                   70841.0
# 9                  120000.0
# 11                 250000.0
# 33                  95968.0
# 38                  75000.0
# ...                     ...
# 78176              336000.0
# 83161             1000000.0
# 92974              269076.0
# 96174               96000.0
# 99868               97233.0
#
# [18166 rows x 3 columns]

# %% [markdown]
# ##### Bộ lọc là các quốc gia 'United States', 'India', 'United Kingdom', 'Germany', 'Canada' trong cột Country

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = (df['Country'].isin(countries))

# %% [markdown]
# ##### Áp dụng bộ lọc trên bộ dữ liệu, thống kê số lượng

# %%
df.loc[filt, 'Country'].value_counts().sort_values(ascending=True)
# Out:
# Country
# Canada             3393
# United Kingdom     6221
# Germany            6459
# India             13721
# United States     20309
# Name: count, dtype: int64

# %% [markdown]
# ##### Đưa ra top 10 các ngôn ngữ được làm việc nhiều nhất

# %%
df['LanguageWorkedWith'].value_counts().head(10)
# Out:
# LanguageWorkedWith
# C#;JavaScript;SQL;HTML;CSS                1347
# JavaScript;PHP;SQL;HTML;CSS               1235
# Java                                      1030
# JavaScript;HTML;CSS                        881
# C#;JavaScript;SQL;TypeScript;HTML;CSS      828
# JavaScript;PHP;SQL;HTML;CSS;Bash/Shell     768
# JavaScript;PHP;HTML;CSS                    725
# Java;JavaScript;SQL;HTML;CSS               530
# C#                                         491
# Python                                     399
# Name: count, dtype: int64

# %% [markdown]
# ##### Bộ lọc để tìm ra các giá trị trong cột 'LanguageWorkedWith' có chứa chuỗi con'Python' hay không, không xem xét các phần tử Nan

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt.value_counts()
# Out:
# LanguageWorkedWith
# False    68496
# True     30359
# Name: count, dtype: int64

# %% [markdown]
# ##### Áp dụng bộ lọc trên cho data

# %%
df.loc[filt]
# Out:
#            Hobby OpenSource         Country         Student  \
# Respondent
# 1            Yes         No           Kenya              No
# 3            Yes        Yes  United Kingdom              No
# 8            Yes         No  United Kingdom              No
# 11           Yes        Yes   United States              No
# 33           Yes        Yes       Australia              No
# ...          ...        ...             ...             ...
# 77960        Yes         No         Germany              No
# 80590        Yes         No     Netherlands  Yes, full-time
# 81545         No         No          Canada              No
# 87736        Yes        Yes           China  Yes, full-time
# 94097        Yes        Yes           India              No
#
#                                         Employment  \
# Respondent
# 1                               Employed part-time
# 3                               Employed full-time
# 8                               Employed full-time
# 11                              Employed full-time
# 33                              Employed full-time
# ...                                            ...
# 77960       Not employed, and not looking for work
# 80590       Not employed, and not looking for work
# 81545       Not employed, and not looking for work
# 87736       Not employed, and not looking for work
# 94097           Not employed, but looking for work
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11          Some college/university study without earning ...
# 33                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77960       Secondary school (e.g. American high school, G...
# 80590       Secondary school (e.g. American high school, G...
# 81545       Secondary school (e.g. American high school, G...
# 87736             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 94097       Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 8           Computer science, computer engineering, or sof...
# 11          Fine arts or performing arts (ex. graphic desi...
# 33          Another engineering discipline (ex. civil, ele...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736       A natural science (ex. biology, chemistry, phy...
# 94097       A social science (ex. anthropology, psychology...
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 8                 10 to 19 employees
# 11              100 to 499 employees
# 33          1,000 to 4,999 employees
# ...                              ...
# 77960                            NaN
# 80590                            NaN
# 81545                            NaN
# 87736                            NaN
# 94097                            NaN
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 8           Back-end developer;Database administrator;Fron...
# 11          Back-end developer;C-suite executive (CEO, CTO...
# 33          Database administrator;Full-stack developer;Mo...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                 Student
# 81545                                                 Student
# 87736           Data scientist or machine learning specialist
# 94097       QA or test developer;Student;System administrator
#
#                  YearsCoding YearsCodingProf          JobSatisfaction  \
# Respondent
# 1                  3-5 years       3-5 years      Extremely satisfied
# 3           30 or more years     18-20 years  Moderately dissatisfied
# 8                  6-8 years       3-5 years     Moderately satisfied
# 11          30 or more years     21-23 years     Moderately satisfied
# 33               15-17 years     12-14 years       Slightly satisfied
# ...                      ...             ...                      ...
# 77960              0-2 years             NaN                      NaN
# 80590              0-2 years             NaN                      NaN
# 81545              0-2 years             NaN                      NaN
# 87736              3-5 years             NaN                      NaN
# 94097              0-2 years       0-2 years                      NaN
#
#                             CareerSatisfaction  \
# Respondent
# 1                          Extremely satisfied
# 3           Neither satisfied nor dissatisfied
# 8                           Slightly satisfied
# 11                        Moderately satisfied
# 33                       Slightly dissatisfied
# ...                                        ...
# 77960                                      NaN
# 80590                                      NaN
# 81545                                      NaN
# 87736                                      NaN
# 94097                                      NaN
#
#                                                 HopeFiveYears  \
# Respondent
# 1           Working as a founder or co-founder of my own c...
# 3           Working in a different or more specialized tec...
# 8           Working in a different or more specialized tec...
# 11                                        Doing the same work
# 33          Working in a different or more specialized tec...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                               JobSearchStatus  \
# Respondent
# 1           I’m not actively looking, but I am open to new...
# 3                             I am actively looking for a job
# 8                             I am actively looking for a job
# 11          I’m not actively looking, but I am open to new...
# 33          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                            LastNewJob  AssessJob1  AssessJob2  AssessJob3  \
# Respondent
# 1                Less than a year ago        10.0         7.0         8.0
# 3               More than 4 years ago         1.0         7.0        10.0
# 8           Between 2 and 4 years ago         8.0         5.0         4.0
# 11          Between 2 and 4 years ago         6.0         3.0         7.0
# 33          Between 2 and 4 years ago         7.0         4.0        10.0
# ...                               ...         ...         ...         ...
# 77960                             NaN         NaN         NaN         NaN
# 80590                             NaN         NaN         NaN         NaN
# 81545                             NaN         NaN         NaN         NaN
# 87736                             NaN         NaN         NaN         NaN
# 94097                             NaN         NaN         NaN         NaN
#
#             AssessJob4  AssessJob5  AssessJob6  AssessJob7  AssessJob8  \
# Respondent
# 1                  1.0         2.0         5.0         3.0         4.0
# 3                  8.0         2.0         5.0         4.0         3.0
# 8                  9.0         1.0         3.0         6.0         2.0
# 11                 4.0         1.0         5.0        10.0         8.0
# 33                 2.0         1.0         5.0         3.0         6.0
# ...                ...         ...         ...         ...         ...
# 77960              NaN         NaN         NaN         NaN         NaN
# 80590              NaN         NaN         NaN         NaN         NaN
# 81545              NaN         NaN         NaN         NaN         NaN
# 87736              NaN         NaN         NaN         NaN         NaN
# 94097              NaN         NaN         NaN         NaN         NaN
#
#             AssessJob9  AssessJob10  AssessBenefits1  AssessBenefits2  \
# Respondent
# 1                  9.0          6.0              NaN              NaN
# 3                  6.0          9.0              1.0              5.0
# 8                 10.0          7.0              1.0              3.0
# 11                 9.0          2.0              1.0              3.0
# 33                 9.0          8.0              3.0              1.0
# ...                ...          ...              ...              ...
# 77960              NaN          NaN              NaN              NaN
# 80590              NaN          NaN              NaN              NaN
# 81545              NaN          NaN              NaN              NaN
# 87736              NaN          NaN              NaN              NaN
# 94097              NaN          NaN              NaN              NaN
#
#             AssessBenefits3  AssessBenefits4  AssessBenefits5  \
# Respondent
# 1                       NaN              NaN              NaN
# 3                       3.0              7.0             10.0
# 8                       4.0             10.0              9.0
# 11                      2.0              9.0             11.0
# 33                      6.0              4.0              5.0
# ...                     ...              ...              ...
# 77960                   NaN              NaN              NaN
# 80590                   NaN              NaN              NaN
# 81545                   NaN              NaN              NaN
# 87736                   NaN              NaN              NaN
# 94097                   NaN              NaN              NaN
#
#             AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# Respondent
# 1                       NaN              NaN              NaN
# 3                       4.0             11.0              9.0
# 8                       2.0              6.0              5.0
# 11                      5.0              8.0              4.0
# 33                      8.0              9.0              7.0
# ...                     ...              ...              ...
# 77960                   NaN              NaN              NaN
# 80590                   NaN              NaN              NaN
# 81545                   NaN              NaN              NaN
# 87736                   NaN              NaN              NaN
# 94097                   NaN              NaN              NaN
#
#             AssessBenefits9  AssessBenefits10  AssessBenefits11  \
# Respondent
# 1                       NaN               NaN               NaN
# 3                       6.0               2.0               8.0
# 8                      11.0               7.0               8.0
# 11                     10.0               7.0               6.0
# 33                      2.0              11.0              10.0
# ...                     ...               ...               ...
# 77960                   NaN               NaN               NaN
# 80590                   NaN               NaN               NaN
# 81545                   NaN               NaN               NaN
# 87736                   NaN               NaN               NaN
# 94097                   NaN               NaN               NaN
#
#             JobContactPriorities1  JobContactPriorities2  \
# Respondent
# 1                             3.0                    1.0
# 3                             3.0                    1.0
# 8                             4.0                    2.0
# 11                            5.0                    1.0
# 33                            2.0                    1.0
# ...                           ...                    ...
# 77960                         NaN                    NaN
# 80590                         NaN                    NaN
# 81545                         NaN                    NaN
# 87736                         NaN                    NaN
# 94097                         NaN                    NaN
#
#             JobContactPriorities3  JobContactPriorities4  \
# Respondent
# 1                             4.0                    2.0
# 3                             5.0                    2.0
# 8                             5.0                    1.0
# 11                            2.0                    3.0
# 33                            4.0                    3.0
# ...                           ...                    ...
# 77960                         NaN                    NaN
# 80590                         NaN                    NaN
# 81545                         NaN                    NaN
# 87736                         NaN                    NaN
# 94097                         NaN                    NaN
#
#             JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# Respondent
# 1                             5.0                  5.0                  6.0
# 3                             4.0                  1.0                  3.0
# 8                             3.0                  2.0                  6.0
# 11                            4.0                  3.0                  7.0
# 33                            5.0                  7.0                  3.0
# ...                           ...                  ...                  ...
# 77960                         NaN                  NaN                  NaN
# 80590                         NaN                  NaN                  NaN
# 81545                         NaN                  NaN                  NaN
# 87736                         NaN                  NaN                  NaN
# 94097                         NaN                  NaN                  NaN
#
#             JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# Respondent
# 1                           7.0                  2.0                  1.0
# 3                           4.0                  5.0                  2.0
# 8                           7.0                  3.0                  1.0
# 11                          2.0                  4.0                  1.0
# 33                          4.0                  5.0                  2.0
# ...                         ...                  ...                  ...
# 77960                       NaN                  NaN                  NaN
# 80590                       NaN                  NaN                  NaN
# 81545                       NaN                  NaN                  NaN
# 87736                       NaN                  NaN                  NaN
# 94097                       NaN                  NaN                  NaN
#
#             JobEmailPriorities6  JobEmailPriorities7  \
# Respondent
# 1                           4.0                  3.0
# 3                           6.0                  7.0
# 8                           5.0                  4.0
# 11                          6.0                  5.0
# 33                          1.0                  6.0
# ...                         ...                  ...
# 77960                       NaN                  NaN
# 80590                       NaN                  NaN
# 81545                       NaN                  NaN
# 87736                       NaN                  NaN
# 94097                       NaN                  NaN
#
#                                                      UpdateCV  \
# Respondent
# 1              My job status or other personal status changed
# 3                           I saw an employer’s advertisement
# 8           I did not receive an expected change in compen...
# 11             My job status or other personal status changed
# 33                          I saw an employer’s advertisement
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                Currency  Salary SalaryType  ConvertedSalary  \
# Respondent
# 1                                   NaN     NaN    Monthly              NaN
# 3           British pounds sterling (£)   51000     Yearly          70841.0
# 8           British pounds sterling (£)   30000        NaN          41671.0
# 11                     U.S. dollars ($)  250000     Yearly         250000.0
# 33              Australian dollars (A$)  120000     Yearly          95968.0
# ...                                 ...     ...        ...              ...
# 77960                               NaN     NaN        NaN              NaN
# 80590                               NaN     NaN        NaN              NaN
# 81545                               NaN     NaN        NaN              NaN
# 87736                               NaN     NaN        NaN              NaN
# 94097                               NaN     NaN        NaN              NaN
#
#            CurrencySymbol                                 CommunicationTools  \
# Respondent
# 1                     KES                                              Slack
# 3                     GBP  Confluence;Office / productivity suite (Micros...
# 8                     GBP  Confluence;Jira;Office / productivity suite (M...
# 11                    USD  Confluence;HipChat;Jira;Office / productivity ...
# 33                    AUD  Confluence;Jira;Office / productivity suite (M...
# ...                   ...                                                ...
# 77960                 NaN                                                NaN
# 80590                 NaN                                                NaN
# 81545                 NaN                                                NaN
# 87736                 NaN                                                NaN
# 94097                 NaN                                                NaN
#
#             TimeFullyProductive  \
# Respondent
# 1           One to three months
# 3           One to three months
# 8             Less than a month
# 11          Three to six months
# 33            Less than a month
# ...                         ...
# 77960                       NaN
# 80590                       NaN
# 81545                       NaN
# 87736                       NaN
# 94097                       NaN
#
#                                                EducationTypes  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 3           Taught yourself a new language, framework, or ...
# 8           Received on-the-job training in software devel...
# 11          Taken an online course in programming or softw...
# 33          Taken an online course in programming or softw...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                               SelfTaughtTypes  \
# Respondent
# 1           The official documentation and/or standards fo...
# 3           The official documentation and/or standards fo...
# 8           The official documentation and/or standards fo...
# 11          The official documentation and/or standards fo...
# 33          The official documentation and/or standards fo...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#            TimeAfterBootcamp  \
# Respondent
# 1                        NaN
# 3                        NaN
# 8                        NaN
# 11                       NaN
# 33                       NaN
# ...                      ...
# 77960                    NaN
# 80590                    NaN
# 81545                    NaN
# 87736                    NaN
# 94097                    NaN
#
#                                              HackathonReasons  AgreeDisagree1  \
# Respondent
# 1                            To build my professional network  Strongly agree
# 3                                                         NaN           Agree
# 8           To improve my general technical skills or prog...        Disagree
# 11                                Because I find it enjoyable  Strongly agree
# 33          To improve my general technical skills or prog...           Agree
# ...                                                       ...             ...
# 77960                                                     NaN             NaN
# 80590                                                     NaN             NaN
# 81545                                                     NaN             NaN
# 87736                                                     NaN             NaN
# 94097                                                     NaN             NaN
#
#                         AgreeDisagree2              AgreeDisagree3  \
# Respondent
# 1                       Strongly agree  Neither Agree nor Disagree
# 3                                Agree  Neither Agree nor Disagree
# 8           Neither Agree nor Disagree           Strongly disagree
# 11                   Strongly disagree           Strongly disagree
# 33          Neither Agree nor Disagree           Strongly disagree
# ...                                ...                         ...
# 77960                              NaN                         NaN
# 80590                              NaN                         NaN
# 81545                              NaN                         NaN
# 87736                              NaN                         NaN
# 94097                              NaN                         NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                  JavaScript;Python;HTML;CSS
# 3                                JavaScript;Python;Bash/Shell
# 8                  Java;JavaScript;Python;TypeScript;HTML;CSS
# 11          Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
# 33                                  C;C++;Go;Python;SQL;Swift
# ...                                                       ...
# 77960                                       Python;Bash/Shell
# 80590                                                  Python
# 81545                                                  Python
# 87736                                                Python;R
# 94097                                             Python;HTML
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1                                  JavaScript;Python;HTML;CSS
# 3                                                   Go;Python
# 8           C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 11                                  Erlang;Go;Python;Rust;SQL
# 33                           C;C++;Go;Python;SQL;Swift;Kotlin
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                Python;R
# 94097                                             Python;HTML
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1           Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 3                                  Redis;PostgreSQL;Memcached
# 8                                                     MongoDB
# 11          Redis;PostgreSQL;Amazon DynamoDB;Apache HBase;...
# 33                                    Redis;PostgreSQL;SQLite
# ...                                                       ...
# 77960                                              SQL Server
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1           Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 3                                                  PostgreSQL
# 8                                                  PostgreSQL
# 11          Redis;PostgreSQL;Amazon DynamoDB;Apache Hive;A...
# 33                    Redis;PostgreSQL;SQLite;Google BigQuery
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                      PlatformWorkedWith  \
# Respondent
# 1                              AWS;Azure;Linux;Firebase
# 3                                                 Linux
# 8                                                 Linux
# 11          Amazon Echo;AWS;iOS;Linux;Mac OS;Serverless
# 33                Android;AWS;iOS;Linux;Mac OS;Firebase
# ...                                                 ...
# 77960                         Windows Desktop or Server
# 80590                                               NaN
# 81545                         Windows Desktop or Server
# 87736                                      Linux;Mac OS
# 94097                                          Firebase
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1                                    AWS;Azure;Linux;Firebase
# 3                                                       Linux
# 8                                                       Linux
# 11                                AWS;Linux;Mac OS;Serverless
# 33          Android;AWS;Google Cloud Platform/App Engine;i...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                            Linux;Mac OS
# 94097                                                Firebase
#
#                    FrameworkWorkedWith     FrameworkDesireNextYear  \
# Respondent
# 1                         Django;React                Django;React
# 3                               Django                       React
# 8                      Angular;Node.js                     Node.js
# 11          Hadoop;Node.js;React;Spark                         NaN
# 33                     Angular;Node.js  Angular;Node.js;TensorFlow
# ...                                ...                         ...
# 77960                              NaN                         NaN
# 80590                              NaN                         NaN
# 81545                              NaN                         NaN
# 87736                              NaN                         NaN
# 94097                              NaN                         NaN
#
#                                                           IDE OperatingSystem  \
# Respondent
# 1                               Komodo;Vim;Visual Studio Code     Linux-based
# 3                          IPython / Jupyter;Sublime Text;Vim     Linux-based
# 8                         IntelliJ;PyCharm;Visual Studio Code     Linux-based
# 11                          IntelliJ;PyCharm;Sublime Text;Vim           MacOS
# 33          Android Studio;Sublime Text;Visual Studio Code...           MacOS
# ...                                                       ...             ...
# 77960                                                     NaN         Windows
# 80590                                                     NaN             NaN
# 81545                                                     NaN         Windows
# 87736                                Atom;PyCharm;RStudio;Vim     Linux-based
# 94097                                Android Studio;Notepad++     Linux-based
#
#            NumberMonitors                                        Methodology  \
# Respondent
# 1                       1                                        Agile;Scrum
# 3                       2                                                NaN
# 8                       2                                              Agile
# 11                      1  Agile;Evidence-based software engineering;Extr...
# 33                      1  Agile;Extreme programming (XP);Formal standard...
# ...                   ...                                                ...
# 77960                   1                                                NaN
# 80590                 NaN                                                NaN
# 81545                   2                                                NaN
# 87736                 NaN                                                NaN
# 94097                   1                                                NaN
#
#                                                VersionControl  \
# Respondent
# 1                                                         Git
# 3                                              Git;Subversion
# 8                                                         Git
# 11                                                        Git
# 33                                                        Git
# ...                                                       ...
# 77960                             I don't use version control
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     Git
# 94097       Git;Copying and pasting files to network share...
#
#                        CheckInCode AdBlocker AdBlockerDisable  \
# Respondent
# 1           Multiple times per day       Yes               No
# 3             A few times per week       Yes              Yes
# 8             A few times per week       Yes              Yes
# 11          Multiple times per day        No              NaN
# 33          Multiple times per day       Yes              Yes
# ...                            ...       ...              ...
# 77960                          NaN       Yes              Yes
# 80590                          NaN       NaN              NaN
# 81545                        Never       Yes               No
# 87736       Multiple times per day       Yes              Yes
# 94097         A few times per week        No              NaN
#
#                                              AdBlockerReasons  \
# Respondent
# 1                                                         NaN
# 3           The website I was visiting asked me to disable it
# 8           I wanted to support the website I was visiting...
# 11                                                        NaN
# 33          The ad-blocking software was causing display i...
# ...                                                       ...
# 77960       The website I was visiting forced me to disabl...
# 80590                                                     NaN
# 81545                                                     NaN
# 87736       I wanted to support the website I was visiting...
# 94097                                                     NaN
#
#                      AdsAgreeDisagree1           AdsAgreeDisagree2  \
# Respondent
# 1                       Strongly agree              Strongly agree
# 3                       Somewhat agree  Neither agree nor disagree
# 8                       Somewhat agree              Somewhat agree
# 11          Neither agree nor disagree              Somewhat agree
# 33                   Somewhat disagree  Neither agree nor disagree
# ...                                ...                         ...
# 77960                Strongly disagree           Strongly disagree
# 80590                              NaN                         NaN
# 81545                Somewhat disagree           Strongly disagree
# 87736       Neither agree nor disagree           Strongly disagree
# 94097                   Somewhat agree              Strongly agree
#
#                      AdsAgreeDisagree3  \
# Respondent
# 1                       Strongly agree
# 3           Neither agree nor disagree
# 8                    Somewhat disagree
# 11          Neither agree nor disagree
# 33                      Somewhat agree
# ...                                ...
# 77960       Neither agree nor disagree
# 80590                              NaN
# 81545                   Strongly agree
# 87736                   Somewhat agree
# 94097                Somewhat disagree
#
#                                                    AdsActions  AdsPriorities1  \
# Respondent
# 1           Saw an online advertisement and then researche...             1.0
# 3                                                         NaN             3.0
# 8           Saw an online advertisement and then researche...             1.0
# 11          Clicked on an online advertisement;Saw an onli...             1.0
# 33                                                        NaN             2.0
# ...                                                       ...             ...
# 77960       Saw an online advertisement and then researche...             1.0
# 80590                                                     NaN             NaN
# 81545       Stopped going to a website because of their ad...             4.0
# 87736                                                     NaN             NaN
# 94097       Clicked on an online advertisement;Saw an onli...             1.0
#
#             AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# Respondent
# 1                      5.0             4.0             7.0             2.0
# 3                      5.0             1.0             4.0             6.0
# 8                      3.0             4.0             2.0             7.0
# 11                     3.0             5.0             4.0             2.0
# 33                     3.0             1.0             7.0             6.0
# ...                    ...             ...             ...             ...
# 77960                  7.0             6.0             2.0             3.0
# 80590                  NaN             NaN             NaN             NaN
# 81545                  5.0             2.0             1.0             6.0
# 87736                  NaN             NaN             NaN             NaN
# 94097                  4.0             2.0             3.0             5.0
#
#             AdsPriorities6  AdsPriorities7  \
# Respondent
# 1                      6.0             3.0
# 3                      7.0             2.0
# 8                      5.0             6.0
# 11                     7.0             6.0
# 33                     4.0             5.0
# ...                    ...             ...
# 77960                  4.0             5.0
# 80590                  NaN             NaN
# 81545                  3.0             7.0
# 87736                  NaN             NaN
# 94097                  6.0             7.0
#
#                                                   AIDangerous  \
# Respondent
# 1           Artificial intelligence surpassing human intel...
# 3                               Increasing automation of jobs
# 8                               Increasing automation of jobs
# 11                      Algorithms making important decisions
# 33                              Increasing automation of jobs
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                           Increasing automation of jobs
# 87736                                                     NaN
# 94097       Artificial intelligence surpassing human intel...
#
#                                                 AIInteresting  \
# Respondent
# 1                       Algorithms making important decisions
# 3                               Increasing automation of jobs
# 8                       Algorithms making important decisions
# 11          Artificial intelligence surpassing human intel...
# 33          Artificial intelligence surpassing human intel...
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                           Increasing automation of jobs
# 87736                                                     NaN
# 94097       Artificial intelligence surpassing human intel...
#
#                                            AIResponsible  \
# Respondent
# 1           The developers or the people creating the AI
# 3           The developers or the people creating the AI
# 8                A governmental or other regulatory body
# 11          The developers or the people creating the AI
# 33                            Prominent industry leaders
# ...                                                  ...
# 77960       The developers or the people creating the AI
# 80590                                                NaN
# 81545       The developers or the people creating the AI
# 87736                                                NaN
# 94097                                             Nobody
#
#                                                      AIFuture  \
# Respondent
# 1           I'm excited about the possibilities more than ...
# 3           I'm excited about the possibilities more than ...
# 8           I'm excited about the possibilities more than ...
# 11          I'm worried about the dangers more than I'm ex...
# 33          I'm excited about the possibilities more than ...
# ...                                                       ...
# 77960       I'm excited about the possibilities more than ...
# 80590                                                     NaN
# 81545       I'm excited about the possibilities more than ...
# 87736                                                     NaN
# 94097       I'm excited about the possibilities more than ...
#
#                      EthicsChoice                      EthicsReport  \
# Respondent
# 1                              No                 Yes, and publicly
# 3           Depends on what it is             Depends on what it is
# 8           Depends on what it is             Depends on what it is
# 11                             No                 Yes, and publicly
# 33                             No  Yes, but only within the company
# ...                           ...                               ...
# 77960                         Yes                                No
# 80590                         NaN                               NaN
# 81545                          No  Yes, but only within the company
# 87736                         NaN                               NaN
# 94097                          No  Yes, but only within the company
#
#                                        EthicsResponsible  \
# Respondent
# 1           Upper management at the company/organization
# 3           Upper management at the company/organization
# 8           Upper management at the company/organization
# 11                  The person who came up with the idea
# 33                            The developer who wrote it
# ...                                                  ...
# 77960               The person who came up with the idea
# 80590                                                NaN
# 81545       Upper management at the company/organization
# 87736                                                NaN
# 94097               The person who came up with the idea
#
#               EthicalImplications StackOverflowRecommend  \
# Respondent
# 1                             Yes       10 (Very Likely)
# 3                             Yes       10 (Very Likely)
# 8           Unsure / I don't know                      7
# 11                            Yes                      7
# 33                            Yes                      9
# ...                           ...                    ...
# 77960                          No       10 (Very Likely)
# 80590                         NaN                    NaN
# 81545                         Yes                      9
# 87736                         NaN                    NaN
# 94097       Unsure / I don't know                      7
#
#                              StackOverflowVisit StackOverflowHasAccount  \
# Respondent
# 1                        Multiple times per day                     Yes
# 3               A few times per month or weekly                     Yes
# 8               A few times per month or weekly                     Yes
# 11              A few times per month or weekly                     Yes
# 33                        Daily or almost daily                     Yes
# ...                                         ...                     ...
# 77960       Less than once per month or monthly                     Yes
# 80590                                       NaN                     NaN
# 81545                    Multiple times per day                      No
# 87736                                       NaN                     NaN
# 94097                    Multiple times per day                     Yes
#
#                                      StackOverflowParticipate  \
# Respondent
# 1           I have never participated in Q&A on Stack Over...
# 3                             A few times per month or weekly
# 8                         Less than once per month or monthly
# 11                        Less than once per month or monthly
# 33                        Less than once per month or monthly
# ...                                                       ...
# 77960                     Less than once per month or monthly
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                    A few times per week
#
#                                             StackOverflowJobs  \
# Respondent
# 1           No, I knew that Stack Overflow had a jobs boar...
# 3                                                         Yes
# 8                                                         Yes
# 11                                                        Yes
# 33                                                        Yes
# ...                                                       ...
# 77960       No, I knew that Stack Overflow had a jobs boar...
# 80590                                                     NaN
# 81545       No, I knew that Stack Overflow had a jobs boar...
# 87736                                                     NaN
# 94097       No, I knew that Stack Overflow had a jobs boar...
#
#                                  StackOverflowDevStory  \
# Respondent
# 1                                                  Yes
# 3                  No, I have one but it's out of date
# 8                  No, I have one but it's out of date
# 11                                                 Yes
# 33          No, I know what it is but I don't have one
# ...                                                ...
# 77960       No, I know what it is but I don't have one
# 80590                                              NaN
# 81545                                              NaN
# 87736                                              NaN
# 94097       No, I know what it is but I don't have one
#
#            StackOverflowJobsRecommend StackOverflowConsiderMember  \
# Respondent
# 1                                 NaN                         Yes
# 3                                   7                         Yes
# 8                                   8                          No
# 11                                  7                          No
# 33                                  6                          No
# ...                               ...                         ...
# 77960                             NaN                         Yes
# 80590                             NaN                         NaN
# 81545                             NaN                          No
# 87736                             NaN                         NaN
# 94097                             NaN                         Yes
#
#                  HypotheticalTools1       HypotheticalTools2  \
# Respondent
# 1              Extremely interested     Extremely interested
# 3           A little bit interested  A little bit interested
# 8           A little bit interested    Not at all interested
# 11            Not at all interested    Not at all interested
# 33          A little bit interested    Not at all interested
# ...                             ...                      ...
# 77960                           NaN                      NaN
# 80590                           NaN                      NaN
# 81545       A little bit interested     Extremely interested
# 87736                           NaN                      NaN
# 94097                           NaN                      NaN
#
#                  HypotheticalTools3       HypotheticalTools4  \
# Respondent
# 1              Extremely interested     Extremely interested
# 3           A little bit interested  A little bit interested
# 8                   Very interested          Very interested
# 11            Not at all interested    Not at all interested
# 33              Somewhat interested      Somewhat interested
# ...                             ...                      ...
# 77960                           NaN                      NaN
# 80590                           NaN                      NaN
# 81545           Somewhat interested  A little bit interested
# 87736                           NaN                      NaN
# 94097                           NaN                      NaN
#
#                  HypotheticalTools5                WakeTime HoursComputer  \
# Respondent
# 1              Extremely interested  Between 5:00 - 6:00 AM  9 - 12 hours
# 3           A little bit interested  Between 6:01 - 7:00 AM   5 - 8 hours
# 8              Extremely interested  Between 7:01 - 8:00 AM  9 - 12 hours
# 11            Not at all interested  Between 8:01 - 9:00 AM  9 - 12 hours
# 33          A little bit interested  Between 6:01 - 7:00 AM  9 - 12 hours
# ...                             ...                     ...           ...
# 77960                           NaN  Between 6:01 - 7:00 AM   1 - 4 hours
# 80590                           NaN                     NaN           NaN
# 81545       A little bit interested  Between 7:01 - 8:00 AM   5 - 8 hours
# 87736                           NaN                     NaN           NaN
# 94097                           NaN          Before 5:00 AM  9 - 12 hours
#
#                     HoursOutside             SkipMeals  \
# Respondent
# 1                    1 - 2 hours                 Never
# 3                30 - 59 minutes                 Never
# 8                30 - 59 minutes  1 - 2 times per week
# 11          Less than 30 minutes  1 - 2 times per week
# 33               30 - 59 minutes                 Never
# ...                          ...                   ...
# 77960            30 - 59 minutes                 Never
# 80590                        NaN                   NaN
# 81545                1 - 2 hours                 Never
# 87736                        NaN                   NaN
# 94097                3 - 4 hours  1 - 2 times per week
#
#                                      ErgonomicDevices  \
# Respondent
# 1                                       Standing desk
# 3                         Ergonomic keyboard or mouse
# 8                                                 NaN
# 11          Standing desk;Fatigue-relieving floor mat
# 33                        Ergonomic keyboard or mouse
# ...                                               ...
# 77960                     Ergonomic keyboard or mouse
# 80590                                             NaN
# 81545                                             NaN
# 87736                                             NaN
# 94097                     Ergonomic keyboard or mouse
#
#                               Exercise Gender         SexualOrientation  \
# Respondent
# 1                 3 - 4 times per week   Male  Straight or heterosexual
# 3            Daily or almost every day   Male  Straight or heterosexual
# 8                 1 - 2 times per week   Male  Straight or heterosexual
# 11          I don't typically exercise   Male  Straight or heterosexual
# 33                3 - 4 times per week   Male  Straight or heterosexual
# ...                                ...    ...                       ...
# 77960             1 - 2 times per week   Male  Straight or heterosexual
# 80590                              NaN    NaN                       NaN
# 81545       I don't typically exercise    NaN                       NaN
# 87736                              NaN    NaN                       NaN
# 94097        Daily or almost every day    NaN                       NaN
#
#                                              EducationParents  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8           Secondary school (e.g. American high school, G...
# 11          Some college/university study without earning ...
# 33                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 77960                                                     NaN
# 80590                                                     NaN
# 81545                                                     NaN
# 87736                                                     NaN
# 94097                                                     NaN
#
#                                           RaceEthnicity                 Age  \
# Respondent
# 1                           Black or of African descent   25 - 34 years old
# 3                          White or of European descent   35 - 44 years old
# 8                          White or of European descent   18 - 24 years old
# 11                         White or of European descent   35 - 44 years old
# 33                                                  NaN   35 - 44 years old
# ...                                                 ...                 ...
# 77960       Middle Eastern;White or of European descent  Under 18 years old
# 80590                                               NaN                 NaN
# 81545                                               NaN                 NaN
# 87736                                               NaN                 NaN
# 94097                                               NaN                 NaN
#
#            Dependents MilitaryUS                         SurveyTooLong  \
# Respondent
# 1                 Yes        NaN  The survey was an appropriate length
# 3                 Yes        NaN  The survey was an appropriate length
# 8                  No        NaN  The survey was an appropriate length
# 11                Yes         No  The survey was an appropriate length
# 33                Yes        NaN               The survey was too long
# ...               ...        ...                                   ...
# 77960              No        NaN  The survey was an appropriate length
# 80590             NaN        NaN                                   NaN
# 81545             NaN        NaN                                   NaN
# 87736             NaN        NaN                                   NaN
# 94097             NaN        NaN                                   NaN
#
#                             SurveyEasy
# Respondent
# 1                            Very easy
# 3                        Somewhat easy
# 8                        Somewhat easy
# 11                           Very easy
# 33          Neither easy nor difficult
# ...                                ...
# 77960       Neither easy nor difficult
# 80590                              NaN
# 81545                              NaN
# 87736                              NaN
# 94097                              NaN
#
# [30359 rows x 128 columns]
